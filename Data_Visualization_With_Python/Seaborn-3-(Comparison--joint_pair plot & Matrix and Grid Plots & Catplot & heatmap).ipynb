# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import warnings
warnings.filterwarnings('ignore') 

import seaborn as sns
import numpy as np
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
plt.figure(figsize=(16,8))
sns.heatmap(penguins.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(penguins.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## catplot()

# %%
sns.catplot(data=penguins, x="species", y="bill_length_mm")

# %%
sns.catplot(data=penguins, x="species", y="bill_length_mm", kind="bar")

# %%
sns.catplot(data=penguins, x="species", y="bill_length_mm", kind="bar", estimator = np.count_nonzero)

# %%
 sns.catplot(data=penguins, x="species", y="bill_length_mm", kind="bar", estimator = np.max)

# %%
 sns.catplot(data=penguins, x="species", y="bill_length_mm", kind="bar", estimator = np.median, ci="sd")

# %%
 sns.catplot(data=penguins, x="species", y="bill_length_mm", kind="bar", estimator = np.median, ci="sd", col="island")

# %%
 sns.catplot(data=penguins, x="species", y="bill_length_mm", kind="bar", estimator = np.median, ci="sd", col="island", hue="sex")

# %%
 sns.catplot(data=penguins, x="species", y="bill_length_mm", kind="box", ci="sd", col="island", hue="sex")

# %%
 sns.catplot(data=penguins, x="island", y="bill_length_mm", kind="box", ci="sd", col="species", hue="sex")

# %%
 sns.catplot(data=penguins, x="island", y="bill_length_mm", kind="box", ci="sd", row="species", hue="sex")

# %% [markdown]
# ## jointplot()

# %%
sns.jointplot(data=penguins, x="bill_depth_mm", y="bill_length_mm")

# %%
sns.jointplot(data=penguins, x="bill_depth_mm", y="bill_length_mm", hue="species")

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.jointplot(data=penguins, x="body_mass_g", y="flipper_length_mm")

# %%
sns.jointplot(data=penguins, x="body_mass_g", y="flipper_length_mm", hue="species")

# %%
sns.jointplot(data=penguins, x="body_mass_g", y="flipper_length_mm", kind="reg")

# %%
sns.jointplot(data=penguins, x="body_mass_g", y="flipper_length_mm", kind="hex")

# %%
sns.jointplot(data=penguins, x="body_mass_g", y="flipper_length_mm", kind="kde", hue="species")

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="flipper_length_mm", kind="kde", hue="species")

# %% [markdown]
# ## pairplot()

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.pairplot(penguins)

# %%
sns.pairplot(penguins, hue="species")

# %%
sns.set_palette(["green", "purple", "red"])
sns.pairplot(penguins, hue="species")

# %%
sns.set_palette(["green", "purple", "red"])

sns.pairplot(penguins, hue="species", corner=True)

# %%
sns.set_palette(["green", "purple", "red"])
sns.pairplot(penguins, hue="species", corner=True, diag_kind="hist")

# %% [markdown]
# ## PairGrid()

# %%
g = sns.PairGrid(penguins)
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(penguins, hue="species")
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(penguins)
g.map_diag(sns.kdeplot)

# %%
g = sns.PairGrid(penguins, hue="species")
g.map_diag(sns.histplot)

# %%
g = sns.PairGrid(penguins, hue="species")
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot)

# %%
g = sns.PairGrid(penguins, hue="species")
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)

# %%
sns.set_palette(["green","blue", "red"])

g = sns.PairGrid(penguins, hue="species")
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)

g.add_legend()

# %%
sns.set_palette(["green","blue", "red"])

g = sns.PairGrid(penguins, hue="species", diag_sharey=False)
g.map_diag(sns.kdeplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)

g.add_legend()

# %% [markdown]
# ## FacetGrid

# %%
g = sns.FacetGrid(data=penguins)
g.map(sns.histplot, "bill_length_mm")

# %%
g = sns.FacetGrid(data=penguins, col="species", row="island", hue="sex")
g.map(sns.kdeplot, "bill_length_mm")

# %%
g = sns.FacetGrid(data=penguins, col="species", row="island", hue="sex")
g.map(sns.scatterplot, "bill_length_mm", "body_mass_g")

# %% [markdown]
# ## heatmap()

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
penguins.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# 3           True   True
# 4          False  False
# ..           ...    ...
# 339         True   True
# 340        False  False
# 341        False  False
# 342        False  False
# 343        False  False
#
# [344 rows x 7 columns]

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.isnull())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr(), annot=True, cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr(), annot=True, cmap="viridis", center=1)  # renk merkezine karar veriyoruz. onun dışında bir özelliği yok
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## clustermap()

# %%
sns.clustermap(penguins.corr(), annot=True)
