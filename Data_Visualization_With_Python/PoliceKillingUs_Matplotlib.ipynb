# %% [markdown]
# # WITH PANDAS AND MATPLOTLIB

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
#
# 1. Number of people by gender
# 1. Kill weapon
# 1. Age of killed people
# 1. Race of killed people
# 1. Killed People According to Races (Pie Chart)
# 1. Most common 15 Name or Surname of killed people
#
# <br>

# %% [markdown]
# read data

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %% [markdown]
# ## 1: Plot number of people by gender

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
kill.gender.value_counts()
# Out:
# M    2428
# F     107
# Name: gender, dtype: int64

# %%
# with pandas

fig, ax = plt.subplots()
kill.gender.value_counts().plot(kind='bar', ax=ax)
# or
# ax = kill.gender.value_counts().plot(kind='bar')

ax.set_title("Gender Distribution", fontsize=15)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.2, p.get_height()+20));

# %%
# with matplotlib 
x= kill.gender.value_counts().index
y= kill.gender.value_counts().values

fig, ax = plt.subplots()
ax.bar(x,y)
ax.set_title("Gender Distribution", fontsize=15)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.35, p.get_height()+20));

# %%
ax.patches
# Out:
# [<matplotlib.patches.Rectangle at 0x1252513ce20>,
#  <matplotlib.patches.Rectangle at 0x1252513cdf0>]

# %%
ax.patches
# Out:
# [<matplotlib.patches.Rectangle at 0x1252513ce20>,
#  <matplotlib.patches.Rectangle at 0x1252513cdf0>]

# %%
ax.patches[1]

# %%
ax.patches[1].get_x()
# Out:
# 0.6

# %%
ax.patches[1].get_height()
# Out:
# 107

# %%
# with matplotlib 
x= kill.gender.value_counts().index
y= kill.gender.value_counts().values

fig, ax = plt.subplots()
ax.bar(x,y)
ax.set_title("Gender Distribution", fontsize=15)

for p in ax.patches:
    ax.text(p.get_x()+0.35, p.get_height()+20 , (p.get_height()) );

# %%
# with matplotlib
x= kill.gender.value_counts().index
y= kill.gender.value_counts().values

plt.bar(x,y)
plt.title("Gender Distribution", fontsize=15)

for i in range(len(x)):
    plt.text( x[i], y[i], str(y[i]), ha='center', va='bottom' )  #,

# %% [markdown]
# ## 2: Plot 7 most common kill weapons

# %%
kill.armed.value_counts()[:10]
# Out:
# gun               1398
# knife              373
# vehicle            177
# unarmed            171
# undetermined       117
# toy weapon         104
# machete             18
# unknown weapon      18
# ax                   9
# Taser                9
# Name: armed, dtype: int64

# %%
kill.armed.value_counts(dropna=False)[:7]
# Out:
# gun               1398
# knife              373
# vehicle            177
# unarmed            171
# undetermined       117
# toy weapon         104
# unknown weapon      18
# Name: armed, dtype: int64

# %%
common_weapons = kill.armed.value_counts(dropna=False)[:7]
common_weapons
# Out:
# gun               1398
# knife              373
# vehicle            177
# unarmed            171
# undetermined       117
# toy weapon         104
# unknown weapon      18
# Name: armed, dtype: int64

# %%
# with pandas
fig, ax = plt.subplots(figsize=(8,5))
common_weapons.plot(kind='bar',ax=ax)
ax.set_xticklabels(common_weapons.index, rotation=45)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+10));

# %%
# with matplotlib
fig, ax = plt.subplots(figsize=(8,5))
ax.bar(x = common_weapons.index, height=common_weapons.values)
ax.set_xticklabels(common_weapons.index, rotation=45)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+10));

# %% [markdown]
# ## 3: Plot number of age of killed people under two groups : Under 25 and Above 25

# %% [markdown]
# Aşağıdaki lambda yönteminde null'ları da above25 olanlara dahil ettiği için kullanmadık. upper ve under ile çözdük.

# %%
kill["age_cat"] = kill["age"].apply(lambda x : "above25" if x > 25 else "below25")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# 1  Not fleeing        False  above25
# 2  Not fleeing        False  below25
# 3  Not fleeing        False  above25
# 4  Not fleeing        False  above25

# %%
under = kill[kill["age"] < 25]["age"].count()
under
# Out:
# 450

# %%
upper = kill[kill["age"] > 25]["age"].count()
upper
# Out:
# 1905

# %%
kill.age.isnull().sum()
# Out:
# 77

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
x = [under, upper]
y = ["under", "upper"]
fig, ax = plt.subplots()

ax.bar(y,x)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1,p.get_height()))

# %%
# with pandas
fig, ax = plt.subplots()
plt.bar(y, x)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.35, p.get_height()+10));

# %% [markdown]
# ## 4: Plot number of killed poeple by race

# %%
race_freq = kill.race.value_counts()
race_freq
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
# with pandas
ax = race_freq.plot.bar()
ax.set_title('Race of killed people',color = 'blue',fontsize=15);

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.05, p.get_height()+10));

# %%
# with matplotlib
fig, ax = plt.subplots()
ax.bar(x=race_freq.index, height=race_freq.values)
ax.set_title('Race of killed people',color = 'blue',fontsize=15);

# %% [markdown]
# ## 5: Killed People According to Races (Pie Chart)

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# 1  Not fleeing        False  above25
# 2  Not fleeing        False  below25
# 3  Not fleeing        False  above25
# 4  Not fleeing        False  above25

# %%
kill.race.unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
kill.race.value_counts(dropna=False)
# Out:
# W      1201
# B       618
# H       423
# NaN     195
# A        39
# N        31
# O        28
# Name: race, dtype: int64

# %% [markdown]
# Problem: missing value on race column.

# %% [markdown]
# **INSTRUCTION-1: Drop the all raws that contain missing value (dropna)**

# %%
kill.race.dropna(inplace=True)

# %%
kill.shape
# Out:
# (2535, 15)

# %% [markdown]
# **INSTRUCTION-2: Demonstrate Race Ratio of Killed People by a Pie Chart (You can use Matplotlib)**

# %%
kill.race.value_counts(dropna=False)
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
labels=kill.race.value_counts().index
labels
# Out:
# Index(['W', 'B', 'H', 'A', 'N', 'O'], dtype='object')

# %%
sizes=kill.race.value_counts().values
sizes
# Out:
# array([1201,  618,  423,   39,   31,   28], dtype=int64)

# %%
explode = (0, 0, 0.1, 0, 0, 0)

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(x = sizes, 
        explode=explode, 
        labels=labels, 
        labeldistance=0.8,
        autopct='%.1f%%',

#         shadow=True, 
        startangle=0,
#         radius=1.5,
       );

# %% [markdown]
# ## 6: Most common 15 Name or Surname of killed people

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# 1  Not fleeing        False  above25
# 2  Not fleeing        False  below25
# 3  Not fleeing        False  above25
# 4  Not fleeing        False  above25

# %%
kill.shape
# Out:
# (2535, 15)

# %%
kill.name.value_counts()
# Out:
# TK TK                       49
# TK Tk                        2
# Eric Harris                  2
# Michael Johnson              2
# Daquan Antonio Westbrook     2
#                             ..
# Norman Campbell              1
# Bruce Zalonka                1
# Shawn Hall                   1
# Kajuan Raye                  1
# Cameron Gover                1
# Name: name, Length: 2481, dtype: int64

# %%
kill[kill.name == 'TK TK']
# Out:
#         id   name      date   manner_of_death         armed   age gender race  \
# 928   1074  TK TK  10/12/15              shot           gun   NaN      M  NaN
# 1397  1584  TK TK  01/06/16              shot           gun   NaN      M  NaN
# 1419  1615  TK TK  09/06/16              shot         baton   NaN      M  NaN
# 1500  1685  TK TK  04/07/16              shot         knife   NaN      M  NaN
# 1646  1848  TK TK  01/09/16  shot and Tasered          pipe   NaN      M    H
# 1825  2037  TK TK  11/11/16  shot and Tasered           NaN   NaN      M  NaN
# 1894  2110  TK TK  08/12/16              shot           gun   NaN      M  NaN
# 1921  2141  TK TK  20/12/16              shot         knife   NaN      M  NaN
# 1927  2154  TK TK  21/12/16              shot         knife   NaN      M  NaN
# 1933  2168  TK TK  23/12/16              shot       vehicle   NaN      M  NaN
# 1936  2164  TK TK  24/12/16              shot           gun   NaN      M  NaN
# 1949  2182  TK TK  30/12/16              shot           gun   NaN      M  NaN
# 2045  2278  TK TK  31/01/17  shot and Tasered         knife   NaN      M    B
# 2078  2319  TK TK  09/02/17              shot  undetermined   NaN      M  NaN
# 2091  2328  TK TK  12/02/17              shot       vehicle   NaN      M  NaN
# 2161  2408  TK TK  08/03/17              shot         knife   NaN      M  NaN
# 2240  2494  TK TK  10/04/17              shot           gun  39.0      M  NaN
# 2247  2505  TK TK  14/04/17              shot           gun   NaN      M  NaN
# 2271  2528  TK TK  25/04/17              shot           gun  24.0      M  NaN
# 2292  2552  TK TK  03/05/17              shot         knife   NaN      M  NaN
# 2307  2565  TK TK  09/05/17              shot           gun   NaN      M  NaN
# 2314  2573  TK TK  11/05/17              shot           gun   NaN      M    H
# 2326  2584  TK TK  15/05/17              shot  undetermined   NaN      M  NaN
# 2330  2587  TK TK  16/05/17              shot         knife  25.0      M  NaN
# 2347  2606  TK TK  24/05/17              shot           gun   NaN      M    H
# 2354  2608  TK TK  28/05/17              shot           gun   NaN      M  NaN
# 2391  2654  TK TK  10/06/17              shot  undetermined   NaN      M  NaN
# 2412  2673  TK TK  17/06/17              shot       vehicle  28.0      F  NaN
# 2418  2683  TK TK  20/06/17  shot and Tasered         knife   NaN      M  NaN
# 2419  2684  TK TK  20/06/17              shot    toy weapon   NaN      M  NaN
# 2435  2698  TK TK  25/06/17              shot           gun   NaN      M  NaN
# 2438  2716  TK TK  28/06/17              shot           gun   NaN      M  NaN
# 2441  2720  TK TK  29/06/17              shot  undetermined   NaN      M  NaN
# 2444  2721  TK TK  30/06/17              shot           gun   NaN      F  NaN
# 2450  2728  TK TK  02/07/17              shot           gun   NaN      M  NaN
# 2452  2732  TK TK  03/07/17              shot           gun   NaN      M  NaN
# 2453  2736  TK TK  03/07/17              shot           gun   NaN      M  NaN
# 2455  2735  TK TK  04/07/17              shot           gun   NaN      M  NaN
# 2465  2748  TK TK  05/07/17              shot  undetermined  24.0      M    H
# 2470  2752  TK TK  07/07/17              shot           gun   NaN      M  NaN
# 2473  2758  TK TK  08/07/17              shot         knife   NaN      M  NaN
# 2485  2770  TK TK  11/07/17              shot           gun   NaN      M  NaN
# 2488  2773  TK TK  12/07/17              shot  blunt object   NaN      M  NaN
# 2495  2780  TK TK  15/07/17              shot           gun  23.0      M  NaN
# 2496  2781  TK TK  15/07/17              shot           gun   NaN      M  NaN
# 2504  2789  TK TK  19/07/17              shot           gun  24.0      M  NaN
# 2520  2804  TK TK  26/07/17              shot           gun  35.0      M  NaN
# 2521  2806  TK TK  26/07/17              shot           gun   NaN      M  NaN
# 2531  2813  TK TK  28/07/17              shot       vehicle   NaN      M  NaN
#
#                  city state  signs_of_mental_illness  threat_level  \
# 928             Hemet    CA                    False        attack
# 1397          Phoenix    AZ                    False        attack
# 1419         Somerton    AZ                    False        attack
# 1500           Rosser    TX                    False         other
# 1646  Huntington Park    CA                    False         other
# 1825       East Point    GA                    False  undetermined
# 1894            Allen    TX                    False        attack
# 1921          Brawley    CA                     True         other
# 1927         Stockton    CA                    False  undetermined
# 1933         El Monte    CA                    False         other
# 1936          Gadsden    AL                    False        attack
# 1949        Pensacola    FL                    False        attack
# 2045        Hollywood    CA                     True        attack
# 2078       Crownpoint    NM                    False  undetermined
# 2091          Terrell    TX                    False         other
# 2161        Riverside    CA                    False         other
# 2240          Houston    TX                    False         other
# 2247         Paterson    NJ                     True        attack
# 2271           Newark    NJ                    False         other
# 2292         San Jose    CA                     True        attack
# 2307      Westminster    CO                    False        attack
# 2314        Arlington    TX                    False        attack
# 2326       Long Beach    CA                    False        attack
# 2330            Tempe    AZ                    False         other
# 2347      Los Angeles    CA                    False        attack
# 2354            Miami    FL                    False        attack
# 2391           Auburn    WA                    False  undetermined
# 2412       Montebello    CA                    False         other
# 2418        Las Vegas    NV                    False         other
# 2419       South Gate    CA                    False        attack
# 2435        Las Vegas    NV                    False        attack
# 2438      Los Angeles    CA                     True        attack
# 2441          Burbank    CA                    False  undetermined
# 2444           Denver    CO                    False        attack
# 2450          Norfolk    VA                    False        attack
# 2452          Fishers    IN                     True        attack
# 2453         Portland    OR                    False        attack
# 2455  Federal Heights    CO                    False  undetermined
# 2465            Vista    CA                    False  undetermined
# 2470       Huntsville    AL                    False        attack
# 2473    Crescent City    FL                     True         other
# 2485    Golden Valley    AZ                    False        attack
# 2488     Grover Beach    CA                    False         other
# 2495    Moreno Valley    CA                     True         other
# 2496        Arlington    TX                    False        attack
# 2504        Fair Oaks    CA                    False        attack
# 2520          Phoenix    AZ                    False        attack
# 2521      San Antonio    TX                    False        attack
# 2531      Albuquerque    NM                    False        attack
#
#              flee  body_camera  age_cat
# 928   Not fleeing        False  below25
# 1397  Not fleeing        False  below25
# 1419  Not fleeing        False  below25
# 1500  Not fleeing         True  below25
# 1646  Not fleeing        False  below25
# 1825          NaN        False  below25
# 1894  Not fleeing        False  below25
# 1921  Not fleeing        False  below25
# 1927  Not fleeing        False  below25
# 1933          Car        False  below25
# 1936         Foot        False  below25
# 1949  Not fleeing        False  below25
# 2045  Not fleeing        False  below25
# 2078          NaN        False  below25
# 2091        Other        False  below25
# 2161  Not fleeing        False  below25
# 2240         Foot         True  above25
# 2247  Not fleeing        False  below25
# 2271          Car        False  below25
# 2292  Not fleeing        False  below25
# 2307  Not fleeing        False  below25
# 2314  Not fleeing        False  below25
# 2326        Other        False  below25
# 2330          NaN        False  below25
# 2347  Not fleeing        False  below25
# 2354          Car        False  below25
# 2391          Car        False  below25
# 2412  Not fleeing        False  above25
# 2418  Not fleeing        False  below25
# 2419        Other        False  below25
# 2435  Not fleeing        False  below25
# 2438  Not fleeing         True  below25
# 2441  Not fleeing        False  below25
# 2444          Car        False  below25
# 2450  Not fleeing        False  below25
# 2452  Not fleeing        False  below25
# 2453         Foot        False  below25
# 2455  Not fleeing        False  below25
# 2465         Foot        False  below25
# 2470          Car        False  below25
# 2473  Not fleeing        False  below25
# 2485         Foot        False  below25
# 2488  Not fleeing        False  below25
# 2495  Not fleeing        False  below25
# 2496         Foot        False  below25
# 2504  Not fleeing        False  below25
# 2520        Other        False  above25
# 2521  Not fleeing        False  below25
# 2531          Car        False  below25

# %%
# Problem: TK TK is most probably not a name or surname. We will clean them.
pairs = kill.name[kill.name != 'TK TK'].str.split()
pairs.head()
# Out:
# 0             [Tim, Elliot]
# 1      [Lewis, Lee, Lembke]
# 2    [John, Paul, Quintero]
# 3        [Matthew, Hoffman]
# 4      [Michael, Rodriguez]
# Name: name, dtype: object

# %%
type(pairs)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **INSTRUCTION : Plot Most common 15 Name OR Surname of killed people**

# %% [raw]
# ### Clue 1: You need to separate the names and surnames because we are asking most common name OR surname.
#
# ### Clue 2 :After seperation make a whole list that contains both names and surnames.
#
# ### Clue 3 : How to separate the name and surname pairs?
#
# >>> pairs = [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')]
# >>> numbers, letters = zip(*pairs)
# >>> numbers
# (1, 2, 3, 4)
# >>> letters
# ('a', 'b', 'c', 'd')
#
# ### Clue 4: You can use Counter() and most_common() built in functions together to find the most common names or surnames, or you can write your own functions for this purpose.

# %%
pairs.shape
# Out:
# (2486,)

# %%
pairs[0]
# Out:
# ['Tim', 'Elliot']

# %%
pairs[0][0]
# Out:
# 'Tim'

# %%
table=[]
for i in pairs:
    for j in i:
        table.append(j)

# %%
len(table)
# Out:
# 5904

# %%
table2=[]
for i in pairs:
    table2.append(i[-1])
len(table2)
# Out:
# 2486

# %%
name= {}
for i in table2:
    if i in name:
        name[i] += 1
    else:
        name[i] = 1
name
# Out:
# {'Elliot': 1,
#  'Lembke': 1,
#  'Quintero': 2,
#  'Hoffman': 2,
#  'Rodriguez': 12,
#  'Brown': 15,
#  'Buck': 3,
#  'Nichols': 3,
#  'Steele': 2,
#  'III': 9,
#  'Wetter': 1,
#  'Sneed': 1,
#  'Abdul-Rasheed': 1,
#  'Brickman': 1,
#  'Jackson': 10,
#  'Simpson': 4,
#  'Barker': 2,
#  'Howard': 2,
#  'Hamby': 1,
#  'Foreman': 2,
#  'Martinez': 9,
#  'Smith': 36,
#  'Barbosa': 1,
#  'Figueroa': 2,
#  "O'Keefe": 1,
#  'McClendon': 2,
#  'Golden': 1,
#  'Goebel': 1,
#  'Jordan': 1,
#  'Schroeder': 2,
#  'Edwards': 6,
#  'Nielson': 1,
#  'Sowell': 2,
#  'Payton': 1,
#  'Reindl': 1,
#  'Ceja': 1,
#  'Massey': 1,
#  'Hall': 13,
#  'Shinwary': 1,
#  'Walker': 3,
#  'Meza': 1,
#  'Brumley': 1,
#  'Guillory': 2,
#  'Castle': 1,
#  'Campbell': 5,
#  'Carr': 1,
#  'Hodge': 4,
#  'Santos-Rodriguez': 1,
#  'Holmes': 3,
#  'Toto': 1,
#  'Meton': 1,
#  'Coignard': 1,
#  'Mesch': 1,
#  'Turner': 4,
#  'Ruiz': 2,
#  'King': 6,
#  'Myler': 1,
#  'Hutchins': 1,
#  'Lopez': 6,
#  'Hernandez': 13,
#  'Kmetz': 1,
#  'Garcia': 11,
#  'Tewa': 1,
#  'Ingram': 1,
#  'Fletcher': 3,
#  'Terry': 2,
#  'Alverson': 1,
#  'Nuu': 1,
#  'Karasek': 1,
#  'Willis': 2,
#  'James': 2,
#  'Marshall': 5,
#  'Reyes': 6,
#  'Bright': 1,
#  'Haglund': 1,
#  'Kassick': 1,
#  'Williams': 18,
#  'Henderson': 5,
#  'Ward': 2,
#  'Purvis': 1,
#  'Lett': 1,
#  'Colon': 2,
#  'Muna': 1,
#  'Jr.': 20,
#  'Atkins': 1,
#  'Johnson': 32,
#  'Hill': 4,
#  'Sawyer': 1,
#  'Allen': 8,
#  'Whittaker': 1,
#  'Flache': 1,
#  'Cordaro': 1,
#  'Paffen': 1,
#  'Hostetter': 1,
#  'Kreyssig': 1,
#  'Luster': 1,
#  'Zambrano-Montes': 1,
#  'Bess': 2,
#  'Fritze': 1,
#  'Watkins': 4,
#  'Stewart': 4,
#  'Harden': 1,
#  'Lara-Rodriguez': 1,
#  'Carlin': 1,
#  'Belk': 1,
#  'Mejia': 1,
#  'Hendrix': 2,
#  'Day': 3,
#  'Steward': 1,
#  'Caldwell': 2,
#  'Casper': 1,
#  'Evans': 9,
#  'Sexton': 2,
#  'Ireland': 1,
#  'Lundy': 1,
#  'Sparks': 1,
#  'Saldivar': 1,
#  'Fonville': 1,
#  'Salazar': 4,
#  'Villalpando': 1,
#  'Grant': 2,
#  'Harris': 10,
#  'Carter': 4,
#  'Norman': 1,
#  'Leonard': 1,
#  'Elrod': 1,
#  'Kohl': 1,
#  'Smashey': 1,
#  'Giaquinta': 1,
#  'Washington': 6,
#  'Biegert': 1,
#  'Lewis': 5,
#  'Spivey': 1,
#  'Long': 6,
#  'Cuevas': 1,
#  'Perez-Lopez': 1,
#  'Biggs': 2,
#  'Harry': 1,
#  'Diaz': 5,
#  'Freeman': 1,
#  'Guilford': 1,
#  'Uribe': 1,
#  'Parker': 5,
#  'Sherrod': 1,
#  'Matkins': 1,
#  'Keunang': 1,
#  'Trieu': 1,
#  'Barrow': 1,
#  'Rhinvil': 1,
#  'Metz': 1,
#  'Cruice': 1,
#  'Lao': 1,
#  'Lawrence': 2,
#  'Navas': 1,
#  'Hubbard': 1,
#  'Vinzant': 1,
#  'Robinson': 9,
#  'Reinhart': 1,
#  'Duarte': 1,
#  'McKillop': 1,
#  'Deckard': 1,
#  'Damon': 3,
#  'Bishop': 1,
#  'Croom': 1,
#  'Mitchell': 3,
#  'Franco': 2,
#  'Greenwell': 1,
#  'Osorio': 1,
#  'Burgess': 4,
#  'Valdez': 4,
#  'Fleury': 1,
#  'Gross': 1,
#  'Liggett': 1,
#  'Driver': 1,
#  'Perez': 7,
#  'Jimenez': 2,
#  'Castilleja': 1,
#  'Reintzel': 1,
#  'Siler': 1,
#  'Boyd': 1,
#  'Tolkinen': 1,
#  'Poole': 1,
#  'Leon': 3,
#  'Shipley': 1,
#  'Owen': 1,
#  'Alexander': 2,
#  'Stone': 1,
#  'Wingo': 1,
#  'Alston': 1,
#  'Childress': 2,
#  'Burdge': 1,
#  'Jones': 14,
#  'Rapp': 1,
#  'Fowler': 1,
#  'White': 6,
#  'Vick': 1,
#  'Ellis': 2,
#  'Page': 1,
#  'Gaver': 1,
#  'Conley': 1,
#  'Healy': 1,
#  'Gates': 2,
#  'Snyder': 3,
#  'Dunham': 1,
#  'Thomas': 7,
#  'Kelly': 1,
#  'Terrazas': 1,
#  'Tassinari': 1,
#  'Choate': 1,
#  'Solis': 1,
#  'Kendrick': 1,
#  'Seifert': 1,
#  'Hockaday': 1,
#  'Oates': 1,
#  'West': 4,
#  'Rooker': 1,
#  'Herbert': 1,
#  'Babb': 1,
#  'Anderson': 15,
#  'Quezada': 1,
#  'Clyde': 1,
#  'Langford': 1,
#  'Hicks': 5,
#  'Rutledge': 1,
#  'Prevatt': 1,
#  'Howell': 1,
#  'Scott': 9,
#  'Noll': 1,
#  'Cockerel': 1,
#  'Hanna': 1,
#  'Myers': 2,
#  'Larsen': 1,
#  'Rose': 1,
#  'Faith': 1,
#  'Bethea': 1,
#  'Weber': 2,
#  'Kimbrell': 1,
#  'Leipold': 1,
#  'Corona': 1,
#  'Reed': 1,
#  'Weaver': 1,
#  'Finley': 1,
#  'Barkley': 1,
#  'Noble': 2,
#  'Shephard': 1,
#  'Adair': 1,
#  'Watson': 3,
#  'Flores': 6,
#  'Velazquez': 1,
#  'Kemp': 1,
#  'Cavazos': 1,
#  'McCarroll': 1,
#  'Tellez': 1,
#  'Sapp': 1,
#  'Foster': 1,
#  'Hlavinka': 1,
#  'Wolfe': 1,
#  'Covarrubias': 1,
#  'Key': 1,
#  'Chapman': 1,
#  'Ramirez': 8,
#  'Efraim': 1,
#  'McGregor': 1,
#  'Vang': 2,
#  'Valadez': 1,
#  'Potts': 1,
#  'Morejon': 1,
#  'Janks': 1,
#  'Hawkins': 3,
#  'Collins': 3,
#  'Dye': 1,
#  'Felix': 1,
#  'Davis': 13,
#  'Patrick': 2,
#  'Hanson': 1,
#  'Genova': 1,
#  'Kellom': 1,
#  'Green': 5,
#  'Deysie': 1,
#  'Chavez-Diaz': 1,
#  'Christian': 3,
#  'Adkins': 1,
#  'Acree': 1,
#  'Nehad': 1,
#  'Sanchez': 7,
#  'Mathena': 1,
#  'Norton': 2,
#  'Soofi': 1,
#  'Grimm': 1,
#  'Asher': 1,
#  'Cook': 3,
#  'Glenn': 2,
#  'Ma': 2,
#  'Frost': 2,
#  'Roy': 2,
#  'Murphy': 3,
#  'Arriguin': 1,
#  'Schwalm': 1,
#  'Cunningham': 1,
#  'Young': 5,
#  'Goldston': 1,
#  'Way': 1,
#  'Stallworth': 1,
#  'Zalonka': 1,
#  'Ouzounian': 1,
#  'Pelletier': 1,
#  'Martin': 6,
#  'Farrar': 1,
#  'Coates': 1,
#  'Wade': 2,
#  'Fiel': 1,
#  'Goodner': 1,
#  'Rials-Torres': 1,
#  'McIntosh': 1,
#  'Gaines': 3,
#  'Gomez': 6,
#  'Colley': 1,
#  'Talbott': 1,
#  'Burtsfield': 1,
#  'Wheeler': 1,
#  'Gandara': 1,
#  'Cooper': 1,
#  'Lowery': 1,
#  'Horn': 1,
#  'Bolin': 1,
#  'Briggs': 3,
#  'Branch': 2,
#  'McAllister': 1,
#  'Sandeno': 1,
#  'Morad': 1,
#  'Hubble': 1,
#  'Morgan': 2,
#  'Strong': 1,
#  'Dothard': 1,
#  'Baker': 9,
#  'Fischer': 2,
#  'Box': 1,
#  'Proctor': 1,
#  'Rivera': 3,
#  'Morris': 5,
#  'Bushey': 1,
#  'Ladd': 1,
#  'Rahim': 1,
#  'Dajani': 1,
#  'Garza': 2,
#  'Baca': 1,
#  'Neal': 1,
#  'Cathers': 1,
#  'Hogg': 1,
#  'Smillie': 1,
#  'Fernandez': 2,
#  'Nevels': 1,
#  'McDaniel': 2,
#  'Warolf': 1,
#  'Linhart': 1,
#  'Hartley': 1,
#  'Bolinger': 1,
#  'Hampton': 1,
#  'Ziegler': 1,
#  'Phillips': 6,
#  'Severe': 1,
#  'Peralta-Lantigua': 1,
#  'Haendiges': 1,
#  'Manyoun': 1,
#  'Boulware': 1,
#  'Terryn': 1,
#  'DeLeon': 1,
#  'Charboneau': 1,
#  'Chappell': 1,
#  'Lanphier': 1,
#  'Tcherniak': 1,
#  'Laboy': 1,
#  'Hummons': 1,
#  'Atencio': 1,
#  'Cockerham': 1,
#  'Simental': 1,
#  'Barrett': 1,
#  'Wicks': 1,
#  'Dyer': 1,
#  'Wilson': 8,
#  'Waddel': 1,
#  'Culbertson': 1,
#  'Harrell': 1,
#  'McCain': 1,
#  'Vanderburgh': 1,
#  'Matt': 1,
#  'Cisneros': 2,
#  'Crittenden': 1,
#  'Bellew': 1,
#  'LaPort': 1,
#  'Lickteig': 1,
#  'Judson': 1,
#  'Landon': 1,
#  'Buckley': 1,
#  'Nguyen': 1,
#  'Larosa': 1,
#  'Juarez': 4,
#  'Camacho': 1,
#  'Julian': 1,
#  'Malone': 2,
#  'Gaby': 1,
#  'Beaty': 2,
#  'Bauer': 2,
#  'Deming': 1,
#  'Holt': 2,
#  'Munroe': 1,
#  'Rogers': 6,
#  'Esty-Lennon': 1,
#  'Sarabia': 1,
#  'Berry': 2,
#  'Hendley': 1,
#  'Burley': 1,
#  'Dujanovic': 1,
#  'Cody': 1,
#  'Dantzler': 1,
#  'Booth': 1,
#  'Blough': 1,
#  'Westrich': 1,
#  'Shatley': 1,
#  'Palmisano': 1,
#  'Hammonds': 1,
#  'Milliner': 1,
#  'Hurtado': 2,
#  'Todora': 1,
#  'Blue': 1,
#  'McSwain': 1,
#  'Maine': 1,
#  'Castaway': 1,
#  'Ellswood': 1,
#  'Lepine': 1,
#  'Benton': 1,
#  'Farmer': 1,
#  'Graham': 2,
#  'Suazo': 1,
#  'Avant': 1,
#  'Crandall': 1,
#  'Kailing': 1,
#  'Gonzalez': 10,
#  'Pippin': 1,
#  'Abdulazeez': 1,
#  'Hack': 1,
#  'Koellner': 1,
#  'Brand': 1,
#  'Dewey': 1,
#  'DuBose': 1,
#  'LeBoeuf': 1,
#  'Francis': 2,
#  'Fuller': 2,
#  'Tyre': 1,
#  'Benitez-Santiago': 1,
#  'Guisherd': 1,
#  'Wolfsteller': 1,
#  'Stortzum': 1,
#  'Edison': 1,
#  'Satre': 1,
#  'Raines': 1,
#  'Gerston': 1,
#  'Olmstead': 1,
#  'Braswell': 1,
#  'Westly': 1,
#  'Hammond': 1,
#  'Milliken': 1,
#  'Falgout': 1,
#  'Forgy': 1,
#  'Perkins': 4,
#  'Vrenon': 1,
#  'Vallejo': 2,
#  'Romero': 4,
#  'Molina': 1,
#  'Hatch': 1,
#  'Serrano': 1,
#  'Reynolds': 3,
#  'Clements': 1,
#  'Malave': 1,
#  'Short': 1,
#  'Ruble': 1,
#  'Avila': 1,
#  'Graves': 2,
#  'Dattilo': 1,
#  'Dieringer': 1,
#  'Hargrove': 1,
#  'Montano': 2,
#  'Galaviz': 1,
#  'Ponce-Galon': 1,
#  'Bertram': 1,
#  'Taylor': 6,
#  'Correa': 1,
#  'Marchese': 1,
#  'Keckhafer': 1,
#  'Clark': 10,
#  'Hunt': 2,
#  'Burr': 1,
#  'Palmer': 2,
#  'Wilkes': 1,
#  'Tompkins': 2,
#  'Quinn': 4,
#  'Alarcon': 1,
#  'Hughes': 1,
#  'Wilks': 1,
#  'Tyree': 1,
#  'Manley': 1,
#  'Unsworth': 1,
#  'Ashley': 2,
#  'Pope': 1,
#  'Castillo': 1,
#  'Jacquez': 1,
#  'Ball-Bey': 1,
#  'Ransom': 1,
#  'Hale': 2,
#  'Gerken': 1,
#  'Tevis': 1,
#  'Herrera': 6,
#  'Walling': 1,
#  'Rushton': 1,
#  'Schneider': 1,
#  'Faison': 2,
#  'Alderman': 1,
#  'Garner': 1,
#  'Compo': 1,
#  'Norris': 2,
#  'Snider': 1,
#  'Maestas': 1,
#  'Tomlinson': 1,
#  'Rudolph': 1,
#  'Arroliga': 1,
#  'Dodd': 1,
#  'Pickard': 1,
#  'Lambrose': 1,
#  'Alehegne': 1,
#  'Hober': 1,
#  'Soriano': 1,
#  'Kumi': 1,
#  'Dial': 1,
#  'Albrecht': 1,
#  'Jr': 3,
#  'Rippley': 1,
#  'Shaw': 1,
#  'Bates': 1,
#  'Centeno': 1,
#  'Meyer': 2,
#  'Kelley': 2,
#  'Lanier': 1,
#  'Lambert': 4,
#  'Wenceslao': 1,
#  'Perry': 4,
#  'Kager': 1,
#  'Yero': 1,
#  'Ibrahim': 1,
#  'Verrett': 1,
#  'Casillas': 1,
#  'Vent': 1,
#  'Kuik': 1,
#  'Holman': 1,
#  'Perdue': 1,
#  'Chau': 1,
#  'Santino': 1,
#  'Foy': 1,
#  'Reid': 2,
#  'Tapia': 2,
#  'Pfleghardt': 1,
#  'Hammen': 1,
#  'Butler': 1,
#  'Brooks': 3,
#  'Johnson-Shanks': 1,
#  'Powell': 2,
#  'Bass': 1,
#  'Chaidez': 1,
#  'Suarez-Ruiz': 1,
#  'Wilhelm': 1,
#  'Gunderman': 1,
#  'Gary': 2,
#  'Price': 3,
#  'Herrell': 1,
#  'Rolland': 1,
#  'Beech': 1,
#  'Pierce': 1,
#  'Wright': 1,
#  'Spaits': 1,
#  'Money': 1,
#  'McKenny': 1,
#  'Wagner': 3,
#  'Osborne': 1,
#  'Torngren': 1,
#  'Berger': 2,
#  'Khammash': 1,
#  'McLeod': 1,
#  'Pinter': 1,
#  'McDole': 1,
#  "O'Grady": 1,
#  'Lemmon': 1,
#  'Blood': 1,
#  'McKinney': 1,
#  'Lerma': 1,
#  'Guzman': 1,
#  'Shell': 1,
#  'Coronado-Martinez': 1,
#  'Prosper': 1,
#  'Lundstrom': 1,
#  'Christen': 1,
#  'Pena': 1,
#  'Jepsen': 1,
#  'Dobbins': 1,
#  'Byrd': 3,
#  'Edgell': 1,
#  'McCallum': 1,
#  'Dunaway': 1,
#  'Jencsik': 1,
#  'Ali': 2,
#  'Pettit': 1,
#  'II': 3,
#  'Lago': 1,
#  'Boitano': 1,
#  'Whitmarsh': 1,
#  'Love': 2,
#  'Combs': 1,
#  'Quay': 1,
#  'Aguilar': 2,
#  'Ortiz': 3,
#  'Lau': 1,
#  'Powers': 2,
#  'Medellin': 1,
#  'Brannon': 1,
#  'Burg': 1,
#  'Villarreal': 2,
#  'Portis': 1,
#  'Lush': 1,
#  'Brennan': 1,
#  'Benitez': 1,
#  'Rangel': 1,
#  'Ball': 2,
#  'Paredes': 1,
#  'Ekizian': 1,
#  'Lopes': 1,
#  'Greenwood': 1,
#  'Gossman': 1,
#  'Galena': 1,
#  'Arnold': 1,
#  'Ludd': 1,
#  'Brock': 1,
#  'Tozzi': 1,
#  'Ulloa': 1,
#  'Hutchinson': 1,
#  'Fude': 1,
#  'Ployhar': 1,
#  'Brunson': 1,
#  'McMillan': 2,
#  'Igbuhay': 1,
#  'Cuyler': 1,
#  'Ashford': 1,
#  'Keeton': 1,
#  'Adams': 3,
#  'Bell': 1,
#  'Swader': 1,
#  'Nole': 1,
#  'Harpham': 1,
#  'Tignor': 1,
#  'Christensen': 1,
#  "O'Quinn": 1,
#  'Yantis': 1,
#  'Covington': 1,
#  'Mardis': 1,
#  'Tyndall': 1,
#  'Mohammad': 1,
#  'Romanoski': 1,
#  'Bigley': 1,
#  'Hohman': 1,
#  'Lemieux': 1,
#  'Smyth': 1,
#  'Simmons': 3,
#  'Cuellar': 1,
#  'Hudson': 2,
#  'Acevedo': 1,
#  'Cano': 2,
#  'Ott': 1,
#  'Mesaros': 1,
#  'Blake': 2,
#  'Jaramillo': 1,
#  'Gavin': 1,
#  'Nero': 1,
#  'Bartkiewicz': 1,
#  'Gamino': 1,
#  'Coleman': 2,
#  'Livingston': 1,
#  'Whitehead': 2,
#  'Noblitt': 1,
#  'Tindall': 1,
#  'Bryant': 2,
#  'Chatham': 1,
#  'Touchstone': 1,
#  'Hartnett': 1,
#  'Meridy': 1,
#  'Dormil': 1,
#  'Napper': 1,
#  'Tarrant': 1,
#  'Pickett': 1,
#  'Grows': 1,
#  'Reyna': 1,
#  'Kirk': 3,
#  'Kirvelay': 1,
#  'Mceniry': 1,
#  'Baez': 1,
#  'Slade': 1,
#  'Speer': 1,
#  'Gullickson': 1,
#  'Close': 1,
#  'McHenry': 1,
#  'Kerns': 1,
#  'Celio': 1,
#  'Grigsby': 1,
#  'Hoang': 1,
#  'Sauceda': 2,
#  'Jozefowicz': 1,
#  'Munoz': 2,
#  'Malik': 1,
#  'Farook': 1,
#  'Woods': 2,
#  'Pacheco': 2,
#  'Lucero': 2,
#  'Stretesky': 1,
#  'Krstic': 1,
#  'Marcellus': 1,
#  'Winesett': 1,
#  'Funk': 1,
#  'Huck': 1,
#  'Azevedo': 1,
#  'Zaramo': 1,
#  'Britton': 1,
#  'Espinal': 1,
#  'Stokes': 2,
#  'Higdon': 1,
#  'Echols': 2,
#  'Rosemond': 1,
#  'Gendreau': 1,
#  'Wickert': 1,
#  'Goodlow': 1,
#  'Eagle': 1,
#  'Robertson': 4,
#  'Wardlow': 1,
#  'Todd': 1,
#  'Carreon': 1,
#  'Villanueva': 2,
#  'Weis': 1,
#  'Leiataua': 1,
#  'McKinnis': 1,
#  'Thomason': 1,
#  'Kimberling': 1,
#  'Saycon': 1,
#  'Alvarez': 3,
#  'Toney': 1,
#  'Duncan': 1,
#  'Yon': 1,
#  'Lauro': 1,
#  'Frerichs': 1,
#  'Scruggs': 2,
#  'Browning': 2,
#  'Quiroz': 1,
#  'Daniels': 2,
#  'Noel': 2,
#  'DeGroat': 1,
#  'Teter': 1,
#  'Leith': 1,
#  'Barsnick': 1,
#  'Stephens': 1,
#  'Hilber': 1,
#  'Matthews': 2,
#  'Gunning': 1,
#  'Sanders': 4,
#  'Griffin': 1,
#  'Ventura': 2,
#  'Westbrook': 2,
#  'Raff': 1,
#  'Niesen': 1,
#  'LeGrier': 1,
#  'Heredia': 1,
#  'Mould': 1,
#  'Trahan': 1,
#  'Achstein': 1,
#  'Velega-Nuufolau': 1,
#  'Hua': 1,
#  'Veach': 1,
#  'Sisson': 1,
#  "O'Brien": 1,
#  'Light': 1,
#  'Wallace': 1,
#  'Senegal': 1,
#  'Nelson': 4,
#  'Maher': 1,
#  'Bukwich': 1,
#  'Thompson': 6,
#  'Zollo': 1,
#  'Hollstein': 1,
#  'Franco-Armenta': 1,
#  'Clay': 1,
#  'Olsen': 2,
#  'Abernathy': 1,
#  'Kent': 1,
#  'Lucas': 1,
#  'Bartley': 1,
#  'Tenbrink': 1,
#  'Lonergan': 1,
#  'Bean': 1,
#  'Richardson': 2,
#  'Bearden': 1,
#  'Meehan': 1,
#  'Holderfield': 1,
#  'Waldron': 1,
#  'Bentley': 1,
#  'Longoria': 2,
#  'Karjalainen': 1,
#  'Hauser': 1,
#  'Layfield': 1,
#  'Bennett': 2,
#  'Fielding': 1,
#  'Shaver': 1,
#  'Szymanski': 1,
#  'Provost': 1,
#  'Caruthers': 1,
#  'Katsouras': 1,
#  'Grady': 1,
#  'Redmond': 1,
#  'Albert': 1,
#  'Lynch': 1,
#  'Alvarado-Morales': 1,
#  'Finicum': 1,
#  'Scanlon': 1,
#  'Bratcher': 1,
#  'Vandarack': 1,
#  'Bailey': 5,
#  'Salyers': 1,
#  'Kalonji': 1,
#  'McClain': 1,
#  'Dew': 1,
#  'Hiatt': 1,
#  'Alegre': 1,
#  'Sinclair': 1,
#  'Bispo': 1,
#  'John': 1,
#  'Alvarado': 2,
#  'Prescott': 1,
#  'Neuman': 1,
#  'Dubrino': 1,
#  'Gassman': 1,
#  'Clarke': 1,
#  'Harless': 1,
#  'Hirko': 1,
#  'Leroy': 1,
#  'Barawis': 1,
#  'Fitzgerald': 2,
#  'Strickland': 1,
#  'Ferry': 2,
#  'Mendez': 4,
#  'Luchsinger': 1,
#  'Laniado': 1,
#  'Longer': 1,
#  'Joseph': 2,
#  'Najera': 2,
#  'Yanagawa': 1,
#  'Vessels': 1,
#  'Nageak': 1,
#  'Birkeland': 1,
#  'Bertoni': 1,
#  'Barry': 1,
#  'Fanfan': 1,
#  'Ridgeway': 1,
#  'Yahia': 1,
#  'Roquemore': 1,
#  'Jaradat': 1,
#  'Stoddart': 1,
#  'Witt': 1,
#  'Andrews': 1,
#  'Meikle': 1,
#  'Dickens': 1,
#  'Gaston': 1,
#  'Quintanilla': 1,
#  'Padron': 1,
#  'Moses': 1,
#  'Dugger': 1,
#  'Rendon': 2,
#  'Camacho-Alvarado': 1,
#  'Perea': 1,
#  'Homer': 1,
#  'Michael': 1,
#  'Sandlin': 1,
#  'Kruger': 1,
#  'Loch': 1,
#  'Stevenson': 1,
#  'Gleason': 2,
#  'Ramos': 4,
#  'Buckner': 1,
#  'Keil': 1,
#  'Wirth': 1,
#  'Miller': 3,
#  'Gunn': 1,
#  'Conti': 1,
#  'Ford': 2,
#  'Spencer': 1,
#  'Fryer': 1,
#  'Grissom': 1,
#  'Denkins': 1,
#  'Corcino': 1,
#  'Sweatt': 2,
#  'Bradley': 1,
#  'Burkhardt': 1,
#  'Ochoa': 1,
#  'Chamberlain': 1,
#  'Stanley': 2,
#  'Bosell': 1,
#  'Ballance': 1,
#  'Minnick': 1,
#  'Torres': 6,
#  'Vitullo': 1,
#  'Rosas': 1,
#  'Selsor': 1,
#  'Chavez': 1,
#  'Casale': 1,
#  'Sheppard': 1,
#  'Meador': 1,
#  'Privott': 1,
#  'Goodman': 1,
#  'Valencia': 3,
#  'Loud': 1,
#  'Tokazowski': 1,
#  'Alachadzhyan': 1,
#  'Cruz': 5,
#  'Grubb': 1,
#  'Deerman': 1,
#  'McCoy': 1,
#  'Colson': 1,
#  'Wooters': 1,
#  'McIver': 1,
#  'Medina': 2,
#  'Penny': 1,
#  'Kong': 1,
#  'Chin': 1,
#  'Nelms': 1,
#  'Mallet': 1,
#  'Giles': 2,
#  'Douglas': 3,
#  'Whitaker': 1,
#  'Ballard': 2,
#  'Dentmond': 1,
#  'Grenon': 1,
#  'Pape': 1,
#  'Gorinski': 1,
#  'Rincon': 1,
#  'Blair': 2,
#  'Hannu': 1,
#  'Dussourd': 1,
#  'Silva': 2,
#  'Mike': 1,
#  'Gonzales': 3,
#  'Sandoval': 1,
#  'Seals': 1,
#  'Blackburn': 1,
#  'McManamon': 1,
#  'Lanahan': 1,
#  'Tsingine': 1,
#  'Guerin': 1,
#  'Ashby': 1,
#  'Melvin': 1,
#  'Fairchild': 1,
#  'Montion': 1,
#  'Cossyleon': 1,
#  'Lagano': 1,
#  'Wood': 3,
#  'Fabela': 1,
#  'Gover': 1,
#  'Boarts': 1,
#  'Mack': 1,
#  'Heraldes': 1,
#  'Doherty': 1,
#  'Cremeans': 1,
#  'Frias': 1,
#  'Gongora': 1,
#  'McIntire': 1,
#  'Flenaugh': 1,
#  'Abbott': 1,
#  'Gulley': 1,
#  'Trujillo': 1,
#  'Loury': 1,
#  'Daman': 1,
#  'Moreno': 3,
#  'Watts': 1,
#  'Wise': 2,
#  'Whitson': 2,
#  'Swatsky': 1,
#  'Boyes': 1,
#  'Arrone': 1,
#  'Tillman': 2,
#  'Thevenin': 1,
#  'Dorsey': 2,
#  'Ackhavong': 1,
#  'Blackmon': 1,
#  'Dufore': 1,
#  'Kirkham': 1,
#  'Hunkin': 1,
#  'Baranishyn': 1,
#  'Semer': 1,
#  'Oakley': 1,
#  'Wakup': 1,
#  ...}

# %%
sorted(name.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('Smith', 36),
#  ('Johnson', 32),
#  ('Jr.', 20),
#  ('Williams', 18),
#  ('Brown', 15),
#  ('Anderson', 15),
#  ('Jones', 14),
#  ('Hall', 13),
#  ('Hernandez', 13),
#  ('Davis', 13)]

# %%
from collections import Counter
most_common_names=Counter(table)
most_common_names
# Out:
# Counter({'Tim': 3,
#          'Elliot': 1,
#          'Lewis': 7,
#          'Lee': 38,
#          'Lembke': 1,
#          'John': 42,
#          'Paul': 19,
#          'Quintero': 2,
#          'Matthew': 24,
#          'Hoffman': 2,
#          'Michael': 91,
#          'Rodriguez': 13,
#          'Kenneth': 19,
#          'Joe': 9,
#          'Brown': 18,
#          'Arnold': 2,
#          'Buck': 3,
#          'Brock': 2,
#          'Nichols': 3,
#          'Autumn': 1,
#          'Steele': 2,
#          'Leslie': 3,
#          'Sapp': 2,
#          'III': 9,
#          'Patrick': 15,
#          'Wetter': 1,
#          'Ron': 2,
#          'Sneed': 1,
#          'Hashim': 1,
#          'Hanif': 1,
#          'Ibn': 1,
#          'Abdul-Rasheed': 1,
#          'Nicholas': 13,
#          'Ryan': 17,
#          'Brickman': 1,
#          'Omarr': 1,
#          'Julian': 3,
#          'Maximillian': 1,
#          'Jackson': 10,
#          'Loren': 3,
#          'Simpson': 4,
#          'James': 57,
#          'Dudley': 1,
#          'Barker': 2,
#          'Artago': 1,
#          'Damon': 6,
#          'Howard': 3,
#          'Thomas': 27,
#          'Hamby': 1,
#          'Jimmy': 5,
#          'Foreman': 2,
#          'Andy': 1,
#          'Martinez': 10,
#          'Tommy': 3,
#          'Smith': 36,
#          'Brian': 12,
#          'Barbosa': 1,
#          'Salvador': 4,
#          'Figueroa': 2,
#          'Edward': 19,
#          "O'Keefe": 1,
#          'Richard': 36,
#          'McClendon': 2,
#          'Marcus': 5,
#          'Golden': 1,
#          'Goebel': 1,
#          'Mario': 8,
#          'Jordan': 5,
#          'Talbot': 1,
#          'Schroeder': 2,
#          'Robert': 48,
#          'Edwards': 6,
#          'Jeffrey': 18,
#          'R.': 10,
#          'Nielson': 1,
#          'Donte': 3,
#          'Sowell': 2,
#          'Kavonda': 1,
#          'Earl': 10,
#          'Payton': 1,
#          'Quincy': 2,
#          'Reed': 2,
#          'Reindl': 1,
#          'Jose': 28,
#          'Ceja': 1,
#          'Nathan': 6,
#          'Massey': 1,
#          'Scott': 27,
#          'Hall': 13,
#          'Zaki': 1,
#          'Shinwary': 1,
#          'Terence': 3,
#          'Walker': 3,
#          'Pablo': 4,
#          'Meza': 1,
#          'Daniel': 46,
#          'Brumley': 1,
#          'Jonathan': 13,
#          'Guillory': 2,
#          'Carter': 5,
#          'Castle': 1,
#          'Campbell': 5,
#          'Dewayne': 3,
#          'Carr': 2,
#          'Todd': 10,
#          'Allen': 23,
#          'Hodge': 4,
#          'Miguel': 10,
#          'Angel': 14,
#          'de': 2,
#          'Santos-Rodriguez': 1,
#          'Isaac': 2,
#          'Holmes': 3,
#          'Andrew': 20,
#          'Toto': 1,
#          'Tiano': 1,
#          'Meton': 1,
#          'Kristiana': 1,
#          'Coignard': 1,
#          'Francis': 14,
#          'Mesch': 1,
#          'Demaris': 1,
#          'Turner': 4,
#          'Antonio': 14,
#          'Espinoza': 1,
#          'Ruiz': 2,
#          'Wendell': 1,
#          'King': 6,
#          'Daryl': 1,
#          'Myler': 1,
#          'Darin': 1,
#          'Hutchins': 1,
#          'Orlando': 1,
#          'Jude': 1,
#          'Lopez': 8,
#          'William': 47,
#          'Jessie': 3,
#          'Hernandez': 13,
#          'Raymond': 11,
#          'Kmetz': 1,
#          'Joshua': 28,
#          'Omar': 6,
#          'Garcia': 14,
#          'David': 57,
#          'Nicolas': 2,
#          'Leland': 2,
#          'Tewa': 1,
#          'Chris': 3,
#          'Ingram': 1,
#          'Jermonte': 1,
#          'Fletcher': 4,
#          'Tiffany': 2,
#          'Terry': 8,
#          'Alan': 12,
#          'Lance': 5,
#          'Alverson': 1,
#          'Matautu': 1,
#          'Nuu': 1,
#          'Cody': 7,
#          'Karasek': 1,
#          'Ralph': 3,
#          'Willis': 3,
#          'Barry': 6,
#          'Marshall': 6,
#          'Victor': 7,
#          'Manuel': 6,
#          'Reyes': 6,
#          'Donnell': 2,
#          'Bright': 1,
#          'Jacob': 7,
#          'Haglund': 1,
#          'Kassick': 1,
#          'Murphy': 4,
#          'Rose': 3,
#          'Ledarius': 1,
#          'D.': 15,
#          'Williams': 18,
#          'Yuvette': 1,
#          'Henderson': 5,
#          'Deshawn': 1,
#          'Ward': 2,
#          'Anthony': 32,
#          'Purvis': 1,
#          'Jeremy': 14,
#          'Lett': 1,
#          'Izzy': 1,
#          'Colon': 2,
#          'Muna': 1,
#          'Joaquin': 1,
#          'Ray': 16,
#          'Robinson': 10,
#          'Jr.': 20,
#          'Markell': 2,
#          'Atkins': 1,
#          'Alfred': 4,
#          'Eugene': 14,
#          'Johnson': 32,
#          'Herbert': 5,
#          'Hill': 4,
#          'Sawyer': 2,
#          'Martin': 14,
#          'Whittaker': 1,
#          'Flache': 1,
#          'Vincent': 5,
#          'Cordaro': 1,
#          'Joseph': 48,
#          'Paffen': 1,
#          'Larry': 8,
#          'Hostetter': 1,
#          'Kreyssig': 1,
#          'Desmond': 3,
#          'Luster': 1,
#          'Zambrano-Montes': 1,
#          'Bess': 2,
#          'Fritze': 1,
#          'Phillip': 10,
#          'Watkins': 4,
#          'Stewart': 4,
#          'Harden': 1,
#          'Andres': 1,
#          'Lara-Rodriguez': 1,
#          'Carlin': 1,
#          'Belk': 1,
#          'Mejia': 2,
#          'Jason': 25,
#          'C.': 8,
#          'Hendrix': 2,
#          'Roy': 9,
#          'Joy': 1,
#          'Day': 3,
#          'Lavall': 1,
#          'Brent': 7,
#          'Means': 1,
#          'Bruce': 8,
#          'Steward': 1,
#          'Lawrence': 6,
#          'Caldwell': 2,
#          'K.': 4,
#          'Casper': 1,
#          'Evans': 9,
#          'Betty': 1,
#          'Sexton': 2,
#          'Ireland': 1,
#          'Lundy': 1,
#          'Douglas': 12,
#          'Sparks': 1,
#          'Pedro': 5,
#          'Juan': 13,
#          'Saldivar': 1,
#          'Janisha': 1,
#          'Fonville': 1,
#          'Alejandro': 7,
#          'Salazar': 4,
#          'Ruben': 6,
#          'Villalpando': 1,
#          'Stanley': 5,
#          'Lamar': 5,
#          'Grant': 4,
#          'Harris': 11,
#          'Moncrief': 1,
#          'Kent': 2,
#          'Norman': 4,
#          'Bradford': 1,
#          'Leonard': 2,
#          'Jerome': 5,
#          'Elrod': 1,
#          'Kohl': 1,
#          'Wayne': 10,
#          'Smashey': 1,
#          'Giaquinta': 1,
#          "A'Donte": 1,
#          'Washington': 6,
#          'Biegert': 1,
#          'Glenn': 5,
#          'Spivey': 1,
#          'Alexander': 13,
#          'Long': 6,
#          'Cuevas': 1,
#          'Amilcar': 1,
#          'Perez-Lopez': 1,
#          'Rodney': 10,
#          'Biggs': 2,
#          'Crystal': 1,
#          'Miley': 1,
#          'Harry': 2,
#          'Ernesto': 5,
#          'Javiar': 1,
#          'Canepa': 1,
#          'Diaz': 5,
#          'Chazsten': 1,
#          'Freeman': 1,
#          'Deven': 1,
#          'Guilford': 1,
#          'Jessica': 2,
#          'Uribe': 1,
#          'Cornelius': 2,
#          'J.': 32,
#          'Parker': 5,
#          'Ian': 3,
#          'Sherrod': 1,
#          'Stephanie': 1,
#          'Donald': 13,
#          'Matkins': 1,
#          'Charly': 1,
#          'Leundeu': 1,
#          'Keunang': 1,
#          'Hung': 1,
#          'Trieu': 1,
#          'Shaquille': 1,
#          'Barrow': 1,
#          'Fednel': 1,
#          'Rhinvil': 1,
#          'Metz': 1,
#          'Derek': 9,
#          'Cruice': 1,
#          'Carl': 4,
#          'Lao': 1,
#          'Tyrone': 6,
#          'Ryerson': 1,
#          'Sergio': 7,
#          'Navas': 1,
#          'Tyson': 2,
#          'Hubbard': 1,
#          'Naeschylus': 1,
#          'Vinzant': 1,
#          'Tony': 2,
#          'Adam': 6,
#          'Reinhart': 1,
#          'Aurelio': 1,
#          'Duarte': 1,
#          'McKillop': 1,
#          'Monique': 1,
#          'Jenee': 1,
#          'Deckard': 1,
#          'Lester': 1,
#          'Cedrick': 1,
#          'Lamont': 7,
#          'Bishop': 1,
#          'Jamie': 7,
#          'Croom': 1,
#          'Christopher': 40,
#          'Mitchell': 5,
#          'Edixon': 1,
#          'Franco': 2,
#          'Theodore': 2,
#          'Greenwell': 1,
#          'Benito': 1,
#          'Osorio': 1,
#          'Dean': 8,
#          'Burgess': 4,
#          'Aaron': 9,
#          'Valdez': 4,
#          'Gilbert': 5,
#          'Fleury': 1,
#          'Russell': 5,
#          'Garnett': 1,
#          'Bobby': 7,
#          'Gross': 1,
#          'Fred': 5,
#          'Liggett': 1,
#          'Driver': 1,
#          'Perez': 8,
#          'Jimenez': 2,
#          'Castilleja': 1,
#          'Clifton': 2,
#          'Reintzel': 1,
#          'Siler': 1,
#          'Troy': 3,
#          'Boyd': 3,
#          'Justin': 10,
#          'Tolkinen': 1,
#          'Poole': 1,
#          'Roberto': 3,
#          'Leon': 4,
#          'Charles': 27,
#          'Shipley': 1,
#          'Declan': 1,
#          'Owen': 1,
#          'Alice': 1,
#          'Jeff': 5,
#          'Kaylene': 1,
#          'Stone': 1,
#          'Garland': 2,
#          'Wingo': 1,
#          'Kendre': 1,
#          'Alston': 1,
#          'Jamison': 2,
#          'Childress': 2,
#          'Burdge': 1,
#          'Shane': 7,
#          'Brandon': 20,
#          'Jones': 14,
#          'Rapp': 1,
#          'Fowler': 1,
#          'White': 6,
#          'Tyrel': 1,
#          'Vick': 1,
#          'Ellis': 2,
#          'Gary': 10,
#          'Page': 2,
#          'Enoch': 1,
#          'Gaver': 1,
#          'Conley': 1,
#          'Healy': 1,
#          'Denzel': 1,
#          'Devin': 5,
#          'Gates': 2,
#          'Stephen': 12,
#          'Snyder': 3,
#          'Walter': 4,
#          'Dunham': 1,
#          'Lorenza': 1,
#          'Kelly': 1,
#          'Terrazas': 1,
#          'Tassinari': 1,
#          'Deanne': 1,
#          'Choate': 1,
#          'Adrian': 5,
#          'Solis': 1,
#          'Kendrick': 1,
#          'Jamalis': 1,
#          'Neil': 4,
#          'Seifert': 1,
#          'Megan': 1,
#          'Hockaday': 1,
#          'Harvey': 1,
#          'Oates': 1,
#          'Angelo': 4,
#          'West': 4,
#          'Rooker': 1,
#          'Byron': 1,
#          'Babb': 1,
#          'Marcell': 1,
#          'Anderson': 15,
#          'Benjamin': 7,
#          'Quezada': 2,
#          'Mya': 1,
#          'Shawn': 9,
#          'Clyde': 3,
#          'Darrin': 3,
#          'Langford': 1,
#          'Hicks': 5,
#          'Eric': 17,
#          'Rutledge': 1,
#          'Prevatt': 1,
#          'Justus': 1,
#          'Howell': 1,
#          'Ethan': 4,
#          'Noll': 1,
#          'Ken': 1,
#          'Cockerel': 1,
#          'Hanna': 1,
#          'Myers': 2,
#          'Tyrell': 1,
#          'Larsen': 1,
#          'Erick': 2,
#          'Faith': 1,
#          'Dexter': 2,
#          'Pernell': 1,
#          'Bethea': 1,
#          'Weber': 2,
#          'Mark': 22,
#          'Gordon': 2,
#          'Kimbrell': 1,
#          'Don': 6,
#          'Jess': 1,
#          'Leipold': 1,
#          'Cresencio': 1,
#          'Corona': 1,
#          'Mack': 2,
#          'Dale': 6,
#          'Weaver': 1,
#          'Colby': 2,
#          'Finley': 1,
#          'Tevin': 1,
#          'Barkley': 1,
#          'Dante': 2,
#          'Noble': 2,
#          'Frank': 4,
#          'Shephard': 1,
#          'W.': 5,
#          'Adair': 1,
#          'Watson': 3,
#          'Flores': 7,
#          'Rodolfo': 1,
#          'Velazquez': 1,
#          'Kemp': 1,
#          'Elias': 2,
#          'Cavazos': 1,
#          'Thaddeus': 2,
#          'McCarroll': 1,
#          'Erik': 3,
#          'Tellez': 1,
#          'Grover': 1,
#          'Foster': 2,
#          'Dana': 3,
#          'Hlavinka': 1,
#          'Santos': 2,
#          'Cortez': 2,
#          'Wolfe': 1,
#          'Covarrubias': 1,
#          'Kimber': 1,
#          'Key': 1,
#          'Luis': 7,
#          'Chapman': 1,
#          'Carlos': 12,
#          'Saavedra': 1,
#          'Ramirez': 8,
#          'Efraim': 1,
#          'Reginald': 3,
#          'McGregor': 1,
#          'Lue': 1,
#          'Vang': 2,
#          'Valadez': 1,
#          'Potts': 1,
#          'Hector': 7,
#          'Morejon': 1,
#          'Karen': 1,
#          'Janks': 1,
#          'Cecil': 1,
#          'Hawkins': 3,
#          'Timmie': 1,
#          'Collins': 3,
#          'Jamal': 5,
#          'Dye': 1,
#          'Felix': 2,
#          'Davis': 14,
#          'Billy': 5,
#          'Albert': 5,
#          'Hanson': 1,
#          'Genova': 1,
#          'Terrance': 1,
#          'Kellom': 1,
#          'Jared': 1,
#          'Green': 5,
#          'Deysie': 1,
#          'Chavez-Diaz': 1,
#          'Alexia': 1,
#          'Christian': 9,
#          'Adkins': 1,
#          'Acree': 1,
#          'Fridoon': 1,
#          'Zalbeg': 1,
#          'Nehad': 1,
#          'Emmanuel': 2,
#          'Sanchez': 7,
#          'Mathena': 1,
#          'Kevin': 16,
#          'Vance': 3,
#          'Norton': 2,
#          'Elton': 1,
#          'Nadir': 2,
#          'Soofi': 1,
#          'Grimm': 1,
#          'Asher': 1,
#          'Roark': 1,
#          'Cook': 3,
#          'Brendon': 1,
#          'Thong': 1,
#          'Kien': 1,
#          'Ma': 2,
#          'A.': 18,
#          'Frost': 2,
#          'Nephi': 2,
#          'Arriguin': 1,
#          'Shaun': 2,
#          'Schwalm': 1,
#          'Dedrick': 1,
#          'Sam': 3,
#          'Cunningham': 1,
#          'Lionel': 4,
#          'Lorenzo': 4,
#          'Young': 5,
#          'Kelvin': 1,
#          'Goldston': 1,
#          'Way': 1,
#          "D'Angelo": 1,
#          'Stallworth': 1,
#          'Zalonka': 1,
#          'Alec': 1,
#          'Ouzounian': 1,
#          'Sean': 6,
#          'Pelletier': 1,
#          'Cary': 1,
#          'Farrar': 1,
#          'Matt': 2,
#          'Coates': 1,
#          'Ronell': 1,
#          'Wade': 3,
#          'Dennis': 11,
#          'Fiel': 1,
#          'Austin': 8,
#          'Goodner': 1,
#          'Timothy': 13,
#          'Alfredo': 2,
#          'Rials-Torres': 1,
#          'McIntosh': 1,
#          'Gaines': 3,
#          'Gomez': 6,
#          'Colley': 1,
#          'Chrislon': 1,
#          'Talbott': 1,
#          'Nikki': 1,
#          'Jo': 2,
#          'Burtsfield': 1,
#          'Wheeler': 1,
#          'Gandara': 1,
#          'Javoris': 1,
#          'Cooper': 1,
#          'Elvin': 1,
#          'Lowery': 1,
#          'Caso': 1,
#          'Horn': 1,
#          'Cassandra': 1,
#          'Bolin': 1,
#          'Briggs': 3,
#          'Millard': 2,
#          'Tallant': 1,
#          'Dalton': 2,
#          'Branch': 2,
#          'McAllister': 1,
#          'Garrett': 2,
#          'Sandeno': 1,
#          'Feras': 1,
#          'Morad': 1,
#          'Simon': 2,
#          'Hubble': 1,
#          'Darrell': 3,
#          'Morgan': 5,
#          'Strong': 1,
#          'Dothard': 1,
#          'Kyle': 9,
#          'Baker': 9,
#          'Nehemiah': 1,
#          'Fischer': 2,
#          'Box': 1,
#          'Ebin': 1,
#          'Proctor': 1,
#          'Tirado': 1,
#          'Rivera': 3,
#          'Morris': 5,
#          'Bushey': 1,
#          'Ladd': 1,
#          'Usaamah': 1,
#          'Rahim': 1,
#          'Kamal': 1,
#          'Dajani': 1,
#          'Garza': 3,
#          'Rudy': 1,
#          'Baca': 1,
#          'Edelmiro': 1,
#          'Ronald': 8,
#          'Neal': 1,
#          'Jesus': 8,
#          'Christie': 1,
#          'Cathers': 1,
#          'Demouria': 1,
#          'Hogg': 1,
#          'Smillie': 1,
#          'Campos': 1,
#          'Fernandez': 2,
#          'Nevels': 1,
#          'Damien': 2,
#          'McDaniel': 2,
#          'Gene': 5,
#          'Rene': 4,
#          'Warolf': 1,
#          'Linhart': 1,
#          'Greg': 2,
#          'Hartley': 1,
#          'QuanDavier': 1,
#          'Bolinger': 1,
#          'Isiah': 1,
#          'Hampton': 1,
#          'Ziegler': 1,
#          'Phillips': 6,
#          'Fritz': 1,
#          'Severe': 1,
#          'Peralta-Lantigua': 1,
#          'Shelly': 2,
#          'Haendiges': 1,
#          'Deng': 1,
#          'Manyoun': 1,
#          'Boulware': 1,
#          'Zane': 1,
#          'Terryn': 1,
#          'Kris': 2,
#          'DeLeon': 1,
#          'Charboneau': 1,
#          'Wendy': 1,
#          'Chappell': 1,
#          'Lanphier': 1,
#          'Oleg': 1,
#          'Tcherniak': 1,
#          'Laboy': 1,
#          'Trepierre': 1,
#          'Hummons': 1,
#          'Louis': 3,
#          'Atencio': 1,
#          'Alfontish': 1,
#          'Cockerham': 1,
#          'Simental': 1,
#          'Monroe': 2,
#          'Barrett': 1,
#          'Eduardo': 4,
#          'Tyler': 10,
#          'Wicks': 1,
#          'Dyer': 1,
#          'Wilson': 10,
#          'Randall': 5,
#          'Waddel': 1,
#          'Taylor': 8,
#          'Culbertson': 1,
#          'Harrell': 1,
#          'Spencer': 4,
#          'McCain': 1,
#          'Jake': 2,
#          'Vanderburgh': 1,
#          'Cisneros': 3,
#          'Crittenden': 1,
#          'Bellew': 1,
#          'LaPort': 1,
#          'Clay': 2,
#          'Lickteig': 1,
#          'Judson': 1,
#          'Kaleb': 2,
#          'Landon': 2,
#          'Buckley': 1,
#          'Ton': 1,
#          'Nguyen': 1,
#          'Emanuel': 1,
#          'Larosa': 1,
#          'Cesar': 4,
#          'Limon': 1,
#          'Juarez': 4,
#          'Arturo': 3,
#          'Oscar': 4,
#          'Camacho': 1,
#          'Elando': 1,
#          'Malone': 2,
#          'Shannon': 3,
#          'Gaby': 1,
#          'Kawanza': 1,
#          'Beaty': 2,
#          'Bryan': 5,
#          'Bauer': 2,
#          'Deming': 1,
#          'Holt': 2,
#          'Munroe': 1,
#          'Johnny': 3,
#          'Rogers': 6,
#          'Hagen': 1,
#          'Esty-Lennon': 1,
#          'Oliva': 1,
#          'Sarabia': 1,
#          'Berry': 2,
#          'Hendley': 1,
#          'Marcellus': 2,
#          'Jamarcus': 1,
#          'Burley': 1,
#          'Dujanovic': 1,
#          'Graciano': 1,
#          'Tremaine': 1,
#          'Dantzler': 1,
#          'Booth': 1,
#          'Blough': 1,
#          'Westrich': 1,
#          'Dallas': 1,
#          'Shatley': 1,
#          'Rocco': 1,
#          'Palmisano': 1,
#          'Hammonds': 1,
#          'Martice': 1,
#          'Milliner': 1,
#          'Cyrus': 1,
#          'Hurtado': 2,
#          'Javon': 1,
#          'Todora': 1,
#          'Freddie': 1,
#          'Blue': 1,
#          'McSwain': 1,
#          'Maine': 1,
#          'Castaway': 1,
#          'Salvado': 1,
#          'Ellswood': 1,
#          'Lepine': 1,
#          'Benton': 1,
#          'Frederick': 4,
#          'Farmer': 1,
#          'Graham': 3,
#          'Rafael': 4,
#          'Suazo': 1,
#          'Chacarion': 1,
#          'Avant': 1,
#          'Crandall': 1,
#          'Kailing': 1,
#          'Anthonie': 1,
#          'Gonzalez': 10,
#          'Pippin': 1,
#          'Mohammad': 4,
#          'Youssef': 1,
#          'Abdulazeez': 1,
#          'Saige': 1,
#          'Hack': 1,
#          'Pierre': 2,
#          'Gabriel': 4,
#          'Koellner': 1,
#          'Samuel': 5,
#          'Jackie': 2,
#          'Brand': 1,
#          'Darrius': 1,
#          'Roman': 2,
#          'Wheat': 1,
#          'Dewey': 1,
#          'DuBose': 1,
#          'LeBoeuf': 1,
#          'Darren': 4,
#          'Fuller': 2,
#          'Jerrod': 2,
#          'Tyre': 3,
#          'Francisco': 7,
#          'Benitez-Santiago': 1,
#          'Andre': 3,
#          'Dontrell': 2,
#          'Devon': 2,
#          'Guisherd': 1,
#          'Dontae': 1,
#          'L.': 15,
#          'Wolfsteller': 1,
#          'Stortzum': 1,
#          'Robbie': 1,
#          'Edison': 1,
#          'Tamala': 1,
#          'Satre': 1,
#          'Seth': 1,
#          'Raines': 1,
#          'Gerston': 1,
#          'Olmstead': 1,
#          'Roger': 6,
#          'Braswell': 1,
#          'Keith': 14,
#          'Khari': 1,
#          'Westly': 1,
#          'Zachary': 3,
#          'Hammond': 2,
#          'Milliken': 1,
#          'Jean': 3,
#          'Falgout': 1,
#          'Forgy': 1,
#          'Perkins': 4,
#          'Vrenon': 1,
#          'Philip': 5,
#          'Vallejo': 2,
#          'Lotari': 1,
#          'Romero': 4,
#          'Molina': 1,
#          'Hatch': 1,
#          'Armando': 4,
#          'Serrano': 1,
#          'Virgil': 1,
#          'Reynolds': 3,
#          'Clements': 1,
#          'Malave': 1,
#          'Franklin': 1,
#          'Short': 1,
#          'Ruble': 1,
#          'Avila': 1,
#          'Darius': 4,
#          'Graves': 2,
#          'Dattilo': 1,
#          'Dieringer': 1,
#          'Keshawn': 1,
#          'Dominique': 2,
#          'Hargrove': 1,
#          'Vincente': 1,
#          'Montano': 2,
#          'Galaviz': 1,
#          'Gustavo': 2,
#          'Ponce-Galon': 1,
#          'Bertram': 1,
#          'Abel': 1,
#          'Correa': 1,
#          'Marchese': 1,
#          'Keckhafer': 1,
#          'Tsombe': 1,
#          'Clark': 11,
#          'Derrick': 2,
#          'Hunt': 2,
#          'Roderick': 1,
#          'Burr': 1,
#          'Shamir': 1,
#          'Terrel': 1,
#          'Palmer': 2,
#          'Wilkes': 1,
#          'Tompkins': 2,
#          'Quinn': 6,
#          'Edrian': 1,
#          'Casey': 3,
#          'George': 10,
#          'Alarcon': 1,
#          'Hughes': 1,
#          'Shull': 1,
#          'Nathaniel': 4,
#          'Wilks': 1,
#          'Redel': 1,
#          'Tyree': 2,
#          'Sorriano': 1,
#          'Asshams': 1,
#          'Pharoah': 1,
#          'Manley': 1,
#          'Unsworth': 1,
#          'Peter': 10,
#          'Ashley': 3,
#          'Jonathon': 2,
#          'Pope': 1,
#          'Castillo': 1,
#          'Steven': 14,
#          'B.': 6,
#          'Jacquez': 1,
#          'Mansur': 1,
#          'Ball-Bey': 1,
#          'Deviere': 1,
#          'Ernel': 1,
#          'Ransom': 1,
#          'Hale': 2,
#          'Gerken': 1,
#          'Jeffory': 1,
#          'Tevis': 1,
#          'Raul': 4,
#          'Herrera': 6,
#          'Timmy': 1,
#          'Walling': 1,
#          'S.': 6,
#          'Rushton': 1,
#          'Schneider': 1,
#          'Faison': 2,
#          'Alderman': 1,
#          'Garner': 1,
#          'Henry': 12,
#          'Compo': 1,
#          'Troledge': 1,
#          'Norris': 2,
#          'Snider': 1,
#          'Marvin': 4,
#          'Maestas': 1,
#          'Curtis': 4,
#          'Tomlinson': 1,
#          'Rudolph': 2,
#          'Arroliga': 1,
#          'Dodd': 1,
#          'Pickard': 1,
#          'Lambrose': 1,
#          'Bertrand': 1,
#          'Yonas': 1,
#          'Alehegne': 1,
#          'Hober': 1,
#          'Soriano': 1,
#          'Kumi': 1,
#          'Dial': 2,
#          'Albrecht': 1,
#          'Cruz': 6,
#          'Jr': 3,
#          'M.': 18,
#          'Rippley': 1,
#          'Cedric': 4,
#          'Maurice': 3,
#          'Shaw': 1,
#          'Arthur': 5,
#          'Bates': 1,
#          'Freddy': 2,
#          'Centeno': 1,
#          'Meyer': 2,
#          'Ramon': 5,
#          'Damiani': 1,
#          'Kelley': 3,
#          'Sully': 1,
#          'Lanier': 1,
#          'Harrison': 2,
#          'Lambert': 4,
#          "La'vante": 1,
#          'Trevon': 2,
#          'Wenceslao': 1,
#          'Delano': 1,
#          'Perry': 5,
#          'India': 3,
#          'Kager': 1,
#          'Yero': 1,
#          'Mohamed': 2,
#          'Ibrahim': 1,
#          'Verrett': 1,
#          'Casimero': 1,
#          'Casillas': 1,
#          'Tristan': 3,
#          'Vent': 1,
#          'Dustin': 4,
#          'Kuik': 1,
#          'Holman': 1,
#          'Perdue': 1,
#          'Chau': 1,
#          'Tian': 1,
#          ...})

# %%
type(most_common_names)
# Out:
# collections.Counter

# %%
most_common_names = most_common_names.most_common(15)
most_common_names
# Out:
# [('Michael', 91),
#  ('James', 57),
#  ('David', 57),
#  ('Robert', 48),
#  ('Joseph', 48),
#  ('William', 47),
#  ('Daniel', 46),
#  ('John', 42),
#  ('Christopher', 40),
#  ('Lee', 38),
#  ('Smith', 36),
#  ('Richard', 36),
#  ('Anthony', 32),
#  ('Johnson', 32),
#  ('J.', 32)]

# %%
df = pd.DataFrame(list(most_common_names), columns=["name_or_surname_most_frequency", "frequency"])
df
# Out:
#    name_or_surname_most_frequency  frequency
# 0                         Michael         91
# 1                           James         57
# 2                           David         57
# 3                          Robert         48
# 4                          Joseph         48
# 5                         William         47
# 6                          Daniel         46
# 7                            John         42
# 8                     Christopher         40
# 9                             Lee         38
# 10                          Smith         36
# 11                        Richard         36
# 12                        Anthony         32
# 13                        Johnson         32
# 14                             J.         32

# %%
# with pandas
fig, ax = plt.subplots(figsize=(15,8))
df.plot(rot=45, kind='bar', ax=ax)

ax.set_ylabel("Frequency")
ax.set_xlabel("Names or Surnames")
ax.set_title("Most common 15 Name OR Surname of killed people")
ax.set_xticklabels(df.name_or_surname_most_frequency, rotation=45)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.2, p.get_height()+0.5));

# %%
# with matplotlib
fig, ax = plt.subplots(figsize=(15,8))
ax.bar(x=df.name_or_surname_most_frequency, height=df.frequency)

ax.set_ylabel("Frequency")
ax.set_xlabel("Names or Surnames")
ax.set_title("Most common 15 Name OR Surname of killed people")
ax.set_xticklabels(df.name_or_surname_most_frequency, rotation=45)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.2, p.get_height()+0.5));

# %%
#alterbnative solition

# %%
table2=[]
for i in pairs:
    table2.append(i[-1])
len(table2)
# Out:
# 2486

# %%
name= {}
for i in table2:
    if i in name:
        name[i] += 1
    else:
        name[i] = 1
len(name)
# Out:
# 1721

# %%
sorted(name.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('Smith', 36),
#  ('Johnson', 32),
#  ('Jr.', 20),
#  ('Williams', 18),
#  ('Brown', 15),
#  ('Anderson', 15),
#  ('Jones', 14),
#  ('Hall', 13),
#  ('Hernandez', 13),
#  ('Davis', 13)]

# %%
df_name = pd.DataFrame(sorted(name.items(), key=lambda x: x[1], reverse=True)[:10],columns=["name","val"])
df_name
# Out:
#         name  val
# 0      Smith   36
# 1    Johnson   32
# 2        Jr.   20
# 3   Williams   18
# 4      Brown   15
# 5   Anderson   15
# 6      Jones   14
# 7       Hall   13
# 8  Hernandez   13
# 9      Davis   13

# %%
# with matplotlib
x=df_name.name
y=df_name.val

fig, ax = plt.subplots(figsize=(15,8))
ax.bar(x=x, height=y)

ax.set_ylabel("Frequency")
ax.set_xlabel(" Surnames")
ax.set_title("Most common 10 Surname of killed people")
ax.set_xticklabels(x, rotation=45)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+0.5));
