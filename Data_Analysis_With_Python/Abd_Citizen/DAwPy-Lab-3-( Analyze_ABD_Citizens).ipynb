# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from file

# %%
df = pd.read_csv("adult.csv")

# %% [markdown]
# # Try to undersstand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features?

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
def val_count(data):
    for i in data.columns:
        print(i)
        print(data[i].value_counts(dropna=False))
        print(25 * "*-", "\n")

# %%
val_count(df)
# Out:
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: age, Length: 74, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# fnlwgt
# 203488    21
# 190290    19
# 120277    19
# 125892    18
# 126569    18
#           ..
# 82649      1
# 193304     1
# 227689     1
# 135891     1
# 250034     1
# Name: fnlwgt, Length: 28523, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# educational-num
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: educational-num, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# relationship
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# gender
# Male      32650
# Female    16192
# Name: gender, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# capital-gain
# 0        44807
# 15024      513
# 7688       410
# 7298       364
# 99999      244
#          ...
# 1111         1
# 6612         1
# 2387         1
# 22040        1
# 1731         1
# Name: capital-gain, Length: 123, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# capital-loss
# 0       46560
# 1902      304
# 1977      253
# 1887      233
# 2415       72
#         ...
# 155         1
# 1870        1
# 2465        1
# 1911        1
# 2080        1
# Name: capital-loss, Length: 99, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# hours-per-week
# 40    22803
# 50     4246
# 45     2717
# 60     2177
# 35     1937
#       ...
# 79        1
# 94        1
# 87        1
# 82        1
# 69        1
# Name: hours-per-week, Length: 96, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Hong                             30
# Thailand                         30
# Cambodia                         28
# Trinadad&Tobago                  27
# Outlying-US(Guam-USVI-etc)       23
# Laos                             23
# Yugoslavia                       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# income
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %%
# df['workclass'].replace('?','Unknown',inplace=True)
unknown_wrkcls = df["workclass"] == "?"

unknown_wrkcls
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: workclass, Length: 48842, dtype: bool

# %%
df[unknown_wrkcls]
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18         ?  103497  Some-college               10
# 6       29         ?  227026       HS-grad                9
# 13      58         ?  299831       HS-grad                9
# 22      72         ?  132015       7th-8th                4
# 35      65         ?  191846       HS-grad                9
# ...    ...       ...     ...           ...              ...
# 48811   35         ?  320084     Bachelors               13
# 48812   30         ?   33811     Bachelors               13
# 48820   71         ?  287372     Doctorate               16
# 48822   41         ?  202822       HS-grad                9
# 48823   72         ?  129912       HS-grad                9
#
#            marital-status occupation   relationship                race  \
# 4           Never-married          ?      Own-child               White
# 6           Never-married          ?      Unmarried               Black
# 13     Married-civ-spouse          ?        Husband               White
# 22               Divorced          ?  Not-in-family               White
# 35     Married-civ-spouse          ?        Husband               White
# ...                   ...        ...            ...                 ...
# 48811  Married-civ-spouse          ?           Wife               White
# 48812       Never-married          ?  Not-in-family  Asian-Pac-Islander
# 48820  Married-civ-spouse          ?        Husband               White
# 48822           Separated          ?  Not-in-family               Black
# 48823  Married-civ-spouse          ?        Husband               White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# 4      Female             0             0              30  United-States
# 6        Male             0             0              40  United-States
# 13       Male             0             0              35  United-States
# 22     Female             0             0               6  United-States
# 35       Male             0             0              40  United-States
# ...       ...           ...           ...             ...            ...
# 48811  Female             0             0              55  United-States
# 48812  Female             0             0              99  United-States
# 48820    Male             0             0              10  United-States
# 48822  Female             0             0              32  United-States
# 48823    Male             0             0              25  United-States
#
#       income
# 4      <=50K
# 6      <=50K
# 13     <=50K
# 22     <=50K
# 35     <=50K
# ...      ...
# 48811   >50K
# 48812  <=50K
# 48820   >50K
# 48822  <=50K
# 48823  <=50K
#
# [2799 rows x 15 columns]

# %%
# df[unknown_wrkcls]["workclass"] = "Unknown"
df.loc[unknown_wrkcls, "workclass"] = "Unknown"

df.iloc[[22]]
# Out:
#     age workclass  fnlwgt education  educational-num marital-status  \
# 22   72   Unknown  132015   7th-8th                4       Divorced
#
#    occupation   relationship   race  gender  capital-gain  capital-loss  \
# 22          ?  Not-in-family  White  Female             0             0
#
#     hours-per-week native-country income
# 22               6  United-States  <=50K

# %%
unknown_occupation = df["occupation"] == "?"

df[unknown_occupation]
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18   Unknown  103497  Some-college               10
# 6       29   Unknown  227026       HS-grad                9
# 13      58   Unknown  299831       HS-grad                9
# 22      72   Unknown  132015       7th-8th                4
# 35      65   Unknown  191846       HS-grad                9
# ...    ...       ...     ...           ...              ...
# 48811   35   Unknown  320084     Bachelors               13
# 48812   30   Unknown   33811     Bachelors               13
# 48820   71   Unknown  287372     Doctorate               16
# 48822   41   Unknown  202822       HS-grad                9
# 48823   72   Unknown  129912       HS-grad                9
#
#            marital-status occupation   relationship                race  \
# 4           Never-married          ?      Own-child               White
# 6           Never-married          ?      Unmarried               Black
# 13     Married-civ-spouse          ?        Husband               White
# 22               Divorced          ?  Not-in-family               White
# 35     Married-civ-spouse          ?        Husband               White
# ...                   ...        ...            ...                 ...
# 48811  Married-civ-spouse          ?           Wife               White
# 48812       Never-married          ?  Not-in-family  Asian-Pac-Islander
# 48820  Married-civ-spouse          ?        Husband               White
# 48822           Separated          ?  Not-in-family               Black
# 48823  Married-civ-spouse          ?        Husband               White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# 4      Female             0             0              30  United-States
# 6        Male             0             0              40  United-States
# 13       Male             0             0              35  United-States
# 22     Female             0             0               6  United-States
# 35       Male             0             0              40  United-States
# ...       ...           ...           ...             ...            ...
# 48811  Female             0             0              55  United-States
# 48812  Female             0             0              99  United-States
# 48820    Male             0             0              10  United-States
# 48822  Female             0             0              32  United-States
# 48823    Male             0             0              25  United-States
#
#       income
# 4      <=50K
# 6      <=50K
# 13     <=50K
# 22     <=50K
# 35     <=50K
# ...      ...
# 48811   >50K
# 48812  <=50K
# 48820   >50K
# 48822  <=50K
# 48823  <=50K
#
# [2809 rows x 15 columns]

# %%
df.loc[unknown_occupation, "occupation"] = "Unknown"
df.iloc[[13]]
# Out:
#     age workclass  fnlwgt education  educational-num      marital-status  \
# 13   58   Unknown  299831   HS-grad                9  Married-civ-spouse
#
#    occupation relationship   race gender  capital-gain  capital-loss  \
# 13    Unknown      Husband  White   Male             0             0
#
#     hours-per-week native-country income
# 13              35  United-States  <=50K

# %%
unknownn_country = df["native-country"] == "?"
df[unknownn_country]
# Out:
#        age         workclass  fnlwgt  education  educational-num  \
# 19      40           Private   85019  Doctorate               16
# 65      41           Private  109912  Bachelors               13
# 83      44      Self-emp-inc  223881    HS-grad                9
# 188     34         State-gov  513100  Bachelors               13
# 253     42       Federal-gov  177937  Bachelors               13
# ...    ...               ...     ...        ...              ...
# 48730   44      Self-emp-inc   71556    Masters               14
# 48750   58      Self-emp-inc  181974  Doctorate               16
# 48773   42  Self-emp-not-inc  217597    HS-grad                9
# 48791   39           Private  107302    HS-grad                9
# 48806   81           Unknown  120478  Assoc-voc               11
#
#               marital-status       occupation   relationship  \
# 19        Married-civ-spouse   Prof-specialty        Husband
# 65             Never-married    Other-service  Not-in-family
# 83        Married-civ-spouse     Craft-repair        Husband
# 188    Married-spouse-absent  Farming-fishing  Not-in-family
# 253            Never-married   Prof-specialty  Not-in-family
# ...                      ...              ...            ...
# 48730     Married-civ-spouse            Sales        Husband
# 48750          Never-married   Prof-specialty  Not-in-family
# 48773               Divorced            Sales      Own-child
# 48791     Married-civ-spouse   Prof-specialty        Husband
# 48806               Divorced          Unknown      Unmarried
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 19     Asian-Pac-Islander    Male             0             0              45
# 65                  White  Female             0             0              40
# 83                  White    Male         99999             0              50
# 188                 Black    Male             0             0              40
# 253                 White    Male             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48730               White    Male             0             0              50
# 48750               White  Female             0             0              99
# 48773               White    Male             0             0              50
# 48791               White    Male             0             0              45
# 48806               White  Female             0             0               1
#
#       native-country income
# 19                 ?   >50K
# 65                 ?  <=50K
# 83                 ?   >50K
# 188                ?  <=50K
# 253                ?  <=50K
# ...              ...    ...
# 48730              ?   >50K
# 48750              ?  <=50K
# 48773              ?  <=50K
# 48791              ?   >50K
# 48806              ?  <=50K
#
# [857 rows x 15 columns]

# %%
df.loc[unknownn_country, "native-country"] = "Unknown"

df.iloc[[19]]
# Out:
#     age workclass  fnlwgt  education  educational-num      marital-status  \
# 19   40   Private   85019  Doctorate               16  Married-civ-spouse
#
#         occupation relationship                race gender  capital-gain  \
# 19  Prof-specialty      Husband  Asian-Pac-Islander   Male             0
#
#     capital-loss  hours-per-week native-country income
# 19             0              45        Unknown   >50K

# %%
# def replacer(df,value,subtitude):
#     for i in df.columns:
#         if df[i].isin([value]).any():
#             print(i, "Column has changed")
#             unknow = df[i] == value
#             df.loc[unknow, i] = subtitude
# replacer(df, "?", "Unknown")

# %%
for i in df.columns:
    df[i].replace("?", "Unknown")  # tüm sütunlarda gezer. ? varsa Unknown olarak değiştirir

# %%
df.education
# Out:
# 0                11th
# 1             HS-grad
# 2          Assoc-acdm
# 3        Some-college
# 4        Some-college
#              ...
# 48837      Assoc-acdm
# 48838         HS-grad
# 48839         HS-grad
# 48840         HS-grad
# 48841         HS-grad
# Name: education, Length: 48842, dtype: object

# %%
df["educational-num"]
# Out:
# 0         7
# 1         9
# 2        12
# 3        10
# 4        10
#          ..
# 48837    12
# 48838     9
# 48839     9
# 48840     9
# 48841     9
# Name: educational-num, Length: 48842, dtype: int64

# %%
df.groupby("education")["educational-num"].value_counts()
# df.groupby("education")["education-num"].count().sort_values()
# Out:
# education     educational-num
# 10th          6                   1389
# 11th          7                   1812
# 12th          8                    657
# 1st-4th       2                    247
# 5th-6th       3                    509
# 7th-8th       4                    955
# 9th           5                    756
# Assoc-acdm    12                  1601
# Assoc-voc     11                  2061
# Bachelors     13                  8025
# Doctorate     16                   594
# HS-grad       9                  15784
# Masters       14                  2657
# Preschool     1                     83
# Prof-school   15                   834
# Some-college  10                 10878
# Name: educational-num, dtype: int64

# %%
df["educational-num"].value_counts() #.sort_values()
# Out:
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: educational-num, dtype: int64

# %%
df.drop("educational-num", axis=1, inplace=True)  # education sütunuyla aynı şeyi ifade ettiği için bunu düşürdük.

# %%
df.isnull().any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# marital-status    False
# occupation        False
# relationship      False
# race              False
# gender            False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country    False
# income            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# gender            0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df.corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076628      0.077229      0.056944        0.071558
# fnlwgt         -0.076628  1.000000     -0.003706     -0.004366       -0.013519
# capital-gain    0.077229 -0.003706      1.000000     -0.031441        0.082157
# capital-loss    0.056944 -0.004366     -0.031441      1.000000        0.054467
# hours-per-week  0.071558 -0.013519      0.082157      0.054467        1.000000

# %%
df.describe(include="all")  # tüm değerleri gösterir. categoric ler dahil
# Out:
#                  age workclass        fnlwgt education      marital-status  \
# count   48842.000000     48842  4.884200e+04     48842               48842
# unique           NaN         9           NaN        16                   7
# top              NaN   Private           NaN   HS-grad  Married-civ-spouse
# freq             NaN     33906           NaN     15784               22379
# mean       38.643585       NaN  1.896641e+05       NaN                 NaN
# std        13.710510       NaN  1.056040e+05       NaN                 NaN
# min        17.000000       NaN  1.228500e+04       NaN                 NaN
# 25%        28.000000       NaN  1.175505e+05       NaN                 NaN
# 50%        37.000000       NaN  1.781445e+05       NaN                 NaN
# 75%        48.000000       NaN  2.376420e+05       NaN                 NaN
# max        90.000000       NaN  1.490400e+06       NaN                 NaN
#
#             occupation relationship   race gender  capital-gain  capital-loss  \
# count            48842        48842  48842  48842  48842.000000  48842.000000
# unique              15            6      5      2           NaN           NaN
# top     Prof-specialty      Husband  White   Male           NaN           NaN
# freq              6172        19716  41762  32650           NaN           NaN
# mean               NaN          NaN    NaN    NaN   1079.067626     87.502314
# std                NaN          NaN    NaN    NaN   7452.019058    403.004552
# min                NaN          NaN    NaN    NaN      0.000000      0.000000
# 25%                NaN          NaN    NaN    NaN      0.000000      0.000000
# 50%                NaN          NaN    NaN    NaN      0.000000      0.000000
# 75%                NaN          NaN    NaN    NaN      0.000000      0.000000
# max                NaN          NaN    NaN    NaN  99999.000000   4356.000000
#
#         hours-per-week native-country income
# count     48842.000000          48842  48842
# unique             NaN             42      2
# top                NaN  United-States  <=50K
# freq               NaN          43832  37155
# mean         40.422382            NaN    NaN
# std          12.391444            NaN    NaN
# min           1.000000            NaN    NaN
# 25%          40.000000            NaN    NaN
# 50%          40.000000            NaN    NaN
# 75%          45.000000            NaN    NaN
# max          99.000000            NaN    NaN

# %%
df.describe()  # numeric değerleri gösterir
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  48842.000000  4.884200e+04  48842.000000  48842.000000    48842.000000
# mean      38.643585  1.896641e+05   1079.067626     87.502314       40.422382
# std       13.710510  1.056040e+05   7452.019058    403.004552       12.391444
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.175505e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.781445e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.376420e+05      0.000000      0.000000       45.000000
# max       90.000000  1.490400e+06  99999.000000   4356.000000       99.000000

# %%
#age
IQR = (48-28)

# %%
48 + 1.5*IQR
# Out:
# 78.0

# %%
df[df["age"] >= 78]["age"].value_counts()  # outlier için 78 yaş üstü sayısına bakıyoruz
# Out:
# 90    53
# 80    38
# 81    37
# 78    34
# 79    30
# 82    15
# 84    13
# 83    11
# 88     6
# 85     5
# 87     3
# 89     2
# 86     1
# Name: age, dtype: int64

# %%
fig, axs = plt.subplots(2,3,figsize=(20,7))
x = 0
y = 0
for column in df.select_dtypes("number").columns:
    df[column].plot(kind = "box", ax = axs[x, y])
    if y < 2:
        y+=1
    else:
        x += 1
        y = 0

# %%
df[df["age"] >= 78].describe()
# Out:
#               age         fnlwgt  capital-gain  capital-loss  hours-per-week
# count  250.000000     250.000000    250.000000     250.00000      250.000000
# mean    82.888000  158100.256000   1918.060000     117.28800       27.500000
# std      4.408309   88707.684175   9585.754419     558.55601       16.866175
# min     78.000000   20101.000000      0.000000       0.00000        1.000000
# 25%     79.000000   97135.250000      0.000000       0.00000       15.000000
# 50%     81.000000  148846.000000      0.000000       0.00000       25.000000
# 75%     87.750000  197086.500000      0.000000       0.00000       40.000000
# max     90.000000  562336.000000  99999.000000    4356.00000       99.000000

# %%
df[(df["age"] >= 78)].sample(20)
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 12446   90           Private  347074  Some-college       Never-married
# 21871   78           Unknown  363134       HS-grad             Widowed
# 48648   90         Local-gov  214594       7th-8th  Married-civ-spouse
# 12229   81  Self-emp-not-inc  184762  Some-college  Married-civ-spouse
# 32173   90           Private   88991     Bachelors  Married-civ-spouse
# 48117   80           Unknown  281768    Assoc-acdm  Married-civ-spouse
# 19492   82           Unknown   29441       7th-8th             Widowed
# 9687    78         Local-gov   87052       HS-grad             Widowed
# 16355   79           Private  124744  Some-college  Married-civ-spouse
# 8313    81           Private   39667       HS-grad  Married-civ-spouse
# 41444   79           Unknown   76641       Masters  Married-civ-spouse
# 40519   90           Unknown  166343       1st-4th             Widowed
# 7539    84           Unknown  163443       7th-8th             Widowed
# 3668    81           Private  176500          12th             Widowed
# 17259   78           Private  182977       HS-grad             Widowed
# 42293   81           Unknown  106765  Some-college             Widowed
# 43863   78  Self-emp-not-inc   82815  Some-college  Married-civ-spouse
# 35453   83      Self-emp-inc  272248       HS-grad            Divorced
# 20351   90           Private  313986          11th       Never-married
# 44076   84           Private  388384       7th-8th  Married-civ-spouse
#
#               occupation    relationship   race  gender  capital-gain  \
# 12446       Adm-clerical       Own-child  White  Female             0
# 21871            Unknown   Not-in-family  White  Female             0
# 48648    Protective-serv         Husband  White    Male          2653
# 12229       Tech-support         Husband  White    Male             0
# 32173    Exec-managerial            Wife  White  Female             0
# 48117            Unknown         Husband  White    Male             0
# 19492            Unknown   Not-in-family  White    Male             0
# 9687        Adm-clerical       Unmarried  White  Female             0
# 16355     Prof-specialty  Other-relative  White    Male             0
# 8313    Transport-moving         Husband  Black    Male             0
# 41444            Unknown         Husband  White    Male         20051
# 40519            Unknown   Not-in-family  Black  Female             0
# 7539             Unknown   Not-in-family  White    Male             0
# 3668               Sales   Not-in-family  White  Female             0
# 17259      Other-service   Not-in-family  Black  Female          2964
# 42293            Unknown       Unmarried  White  Female             0
# 43863       Craft-repair         Husband  White    Male             0
# 35453              Sales   Not-in-family  White    Male             0
# 20351  Handlers-cleaners       Own-child  White    Male             0
# 44076     Prof-specialty         Husband  Black    Male             0
#
#        capital-loss  hours-per-week native-country income
# 12446          1944              12  United-States  <=50K
# 21871             0               1  United-States  <=50K
# 48648             0              40  United-States  <=50K
# 12229             0              25         Greece  <=50K
# 32173             0              40        England   >50K
# 48117             0               4  United-States  <=50K
# 19492             0               5  United-States  <=50K
# 9687              0               5  United-States  <=50K
# 16355             0              20  United-States  <=50K
# 8313              0              20  United-States  <=50K
# 41444             0              40         Poland   >50K
# 40519             0              40  United-States  <=50K
# 7539              0               3  United-States  <=50K
# 3668              0              30  United-States  <=50K
# 17259             0              40  United-States  <=50K
# 42293             0               4  United-States  <=50K
# 43863             0               3  United-States   >50K
# 35453             0              20  United-States  <=50K
# 20351             0              40  United-States  <=50K
# 44076             0              10  United-States  <=50K

# %%
df[(df["hours-per-week"] == 99)].sample(20)
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 48812   30           Unknown   33811     Bachelors       Never-married
# 24935   30           Private  103596       HS-grad       Never-married
# 35680   39      Self-emp-inc  163057  Some-college            Divorced
# 8677    73  Self-emp-not-inc  228899       7th-8th       Never-married
# 12128   57  Self-emp-not-inc  105824          11th  Married-civ-spouse
# 2392    34           Private  230246       HS-grad       Never-married
# 44090   30           Private   39386  Some-college  Married-civ-spouse
# 1156    48           Unknown  117054       5th-6th            Divorced
# 31815   29           Private  167716       HS-grad            Divorced
# 37428   39           Private  348521  Some-college  Married-civ-spouse
# 901     37           Private  112158       HS-grad  Married-civ-spouse
# 7178    34           Private  132544  Some-college  Married-civ-spouse
# 39679   66           Private   28367     Bachelors  Married-civ-spouse
# 10942   44  Self-emp-not-inc   52505  Some-college  Married-civ-spouse
# 12486   32      Self-emp-inc  204470  Some-college  Married-civ-spouse
# 39930   45           Private  390368  Some-college  Married-civ-spouse
# 47035   31           Private   33124   Prof-school       Never-married
# 35810   38           Private   66326       HS-grad  Married-civ-spouse
# 12314   53  Self-emp-not-inc  276369       HS-grad  Married-civ-spouse
# 42531   36  Self-emp-not-inc  257250     Assoc-voc  Married-civ-spouse
#
#              occupation    relationship                race  gender  \
# 48812           Unknown   Not-in-family  Asian-Pac-Islander  Female
# 24935   Protective-serv   Not-in-family               White    Male
# 35680      Craft-repair   Not-in-family               White    Male
# 8677       Adm-clerical   Not-in-family               White  Female
# 12128   Farming-fishing         Husband               White    Male
# 2392       Craft-repair   Not-in-family               White    Male
# 44090   Exec-managerial         Husband               Black    Male
# 1156            Unknown   Not-in-family               White    Male
# 31815     Other-service       Unmarried               White  Female
# 37428   Farming-fishing         Husband               White    Male
# 901        Craft-repair         Husband               White    Male
# 7178              Sales         Husband               White    Male
# 39679   Priv-house-serv  Other-relative               White    Male
# 10942   Farming-fishing         Husband               White    Male
# 12486             Sales         Husband               White    Male
# 39930             Sales         Husband               Black    Male
# 47035    Prof-specialty   Not-in-family               White  Female
# 35810  Transport-moving         Husband               White    Male
# 12314   Farming-fishing         Husband               White    Male
# 42531   Farming-fishing         Husband               White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48812             0             0              99  United-States  <=50K
# 24935             0             0              99  United-States  <=50K
# 35680             0             0              99  United-States  <=50K
# 8677              0             0              99  United-States  <=50K
# 12128             0             0              99  United-States  <=50K
# 2392           2202             0              99  United-States  <=50K
# 44090             0             0              99  United-States  <=50K
# 1156              0             0              99  United-States  <=50K
# 31815             0             0              99  United-States  <=50K
# 37428             0          2415              99  United-States   >50K
# 901            7688             0              99  United-States   >50K
# 7178              0             0              99  United-States  <=50K
# 39679             0             0              99  United-States  <=50K
# 10942             0             0              99  United-States  <=50K
# 12486             0             0              99  United-States   >50K
# 39930         15024             0              99  United-States   >50K
# 47035             0             0              99  United-States  <=50K
# 35810             0             0              99  United-States  <=50K
# 12314             0             0              99  United-States  <=50K
# 42531             0             0              99  United-States  <=50K

# %%
df[(df["hours-per-week"] == 99)][["age"]].agg(["median", "mean", "count"])
# Out:
#                age
# median   42.000000
# mean     44.007299
# count   137.000000

# %%
df[(df["age"] >= 78) & (df["hours-per-week"] == 99)]
# Out:
#        age    workclass  fnlwgt education marital-status        occupation  \
# 8427    90  Federal-gov  311184   Masters       Divorced    Prof-specialty
# 31637   90      Private   90523   HS-grad        Widowed  Transport-moving
#
#         relationship   race gender  capital-gain  capital-loss  \
# 8427   Not-in-family  White   Male             0             0
# 31637      Unmarried  White   Male             0             0
#
#        hours-per-week native-country income
# 8427               99  United-States  <=50K
# 31637              99  United-States  <=50K

# %%
99/7  # günde 14.14 saat çalışıyor
# Out:
# 14.142857142857142

# %%
df.groupby(by = ["age", "workclass"])["hours-per-week"].agg(["mean", "median", "min", "max", "count"]).loc[90]
# Out:
#                        mean  median  min  max  count
# workclass
# Federal-gov       64.500000    64.5   30   99      2
# Local-gov         40.000000    40.0   20   60      5
# Private           39.114286    40.0   10   99     35
# Self-emp-not-inc  41.400000    45.0   12   60      5
# Unknown           20.750000    12.5    4   40      8

# %%
df.drop(index=[8427, 31637], inplace=True)

# %% [markdown]
# ---
# # How many of each race are represented in this dataset?
# ---

# %%
race_count = df.race.value_counts()  # ırkların sayısına bakıyoruz
race_count
# Out:
# White                 41760
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh()  # beyazlar yoğunlukta
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# # What is the average age of men/women?
# ---

# %%
average_age_men = df.loc[df["gender"] == "Male", "age"].mean()  # erkeklerin yaş ortalaması
average_age_men
# Out:
# 39.49130115167851

# %%
round(average_age_men, 1)
# Out:
# 39.5

# %%
df.loc[df["gender"] == "Male", "age"].mode()
# Out:
# 0    35
# dtype: int64

# %%
df.loc[df["gender"] == "Male", "age"].std()
# Out:
# 13.40743411917089

# %%
plt.figure(figsize = (15,7))
df.loc[df["gender"] == "Male", "age"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
average_age_women = df.loc[df["gender"] == "Female", "age"].mean()  # kadınların yaş ortalaması
average_age_women
# Out:
# 36.92798913043478

# %%
df.loc[df["gender"] == "Female", "age"].median()
# Out:
# 35.0

# %%
df.loc[df["gender"] == "Female", "age"].mode()
# Out:
# 0    23
# dtype: int64

# %%
df.loc[df["gender"] == "Female", "age"].std()
# Out:
# 14.13742261724767

# %%
plt.figure(figsize = (15, 7))
df.loc[df["gender"] == "Female", "age"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# # What is the percentage of people who have a Bachelor's degree?
# ---

# %%
df.groupby("education").education.count()
# Out:
# education
# 10th             1389
# 11th             1812
# 12th              657
# 1st-4th           247
# 5th-6th           509
# 7th-8th           955
# 9th               756
# Assoc-acdm       1601
# Assoc-voc        2061
# Bachelors        8025
# Doctorate         594
# HS-grad         15783
# Masters          2656
# Preschool          83
# Prof-school       834
# Some-college    10878
# Name: education, dtype: int64

# %%
df["education"].value_counts()
# Out:
# HS-grad         15783
# Some-college    10878
# Bachelors        8025
# Masters          2656
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
upper = df.groupby("education").education.count().loc["Bachelors"]  # 8025 (lisans mezunu sayısı)

lower = df.groupby("education").education.count().sum()  # 48840 (tüm okuyoanlar)

percentage_bachelors = upper / lower *100 # lisans mezununun tüm okuyanlara oranı (yüzdesi)

percentage_bachelors
# Out:
# 16.43120393120393

# %%
upper
# Out:
# 8025

# %%
lower
# Out:
# 48840

# %%
df["education"].value_counts(normalize=True)  # normalize ile tüm eğitim seviyelerinin sıklığını değil oranları döndürdük
# Out:
# HS-grad         0.323157
# Some-college    0.222727
# Bachelors       0.164312
# Masters         0.054382
# Assoc-voc       0.042199
# 11th            0.037101
# Assoc-acdm      0.032781
# 10th            0.028440
# 7th-8th         0.019554
# Prof-school     0.017076
# 9th             0.015479
# 12th            0.013452
# Doctorate       0.012162
# 5th-6th         0.010422
# 1st-4th         0.005057
# Preschool       0.001699
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors, 1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : %{round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : %16.4

# %% [markdown]
# ---
# # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# ---
